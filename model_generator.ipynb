# %% [markdown]
# # Lab 5: Google Speech Commands

# %% [markdown]
# ## Imports

# %%
import copy
import requests
import json
from urllib.parse import urlparse
import wave
from pathlib import Path
import os
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, Conv1D, AvgPool1D, MaxPool1D, ZeroPadding1D, BatchNormalization, Flatten, Dense, Activation, Dropout, SeparableConv1D, GlobalMaxPool1D, GlobalAveragePooling1D, MaxPooling1D, ReLU, LeakyReLU
from keras.activations import softmax
from keras.utils import get_file
from keras.utils import to_categorical
import librosa
import soundfile as sf
import random
from sklearn.model_selection import train_test_split
from pydub import AudioSegment

# %% [markdown]
# ## Download, cache and extract Google Speech Commands

# %%
def sanitize_filename(name):
    invalid_chars = '<>:"/\\|?*'
    for char in invalid_chars:
        name = name.replace(char, '_')
    return name

def download_file(url, filepath):
    print(f"Downloading from {url} to {filepath}...")
    response = requests.get(url)
    response.raise_for_status()  # Va lever une exception si la requête a échoué

    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    with open(filepath, 'wb') as f:
        f.write(response.content)

urls = [
    'https://xeno-canto.org/api/2/recordings?query=type:song+gen:emberiza',
    'https://xeno-canto.org/api/2/recordings?query=type:song+gen:muscicapa',
    'https://xeno-canto.org/api/2/recordings?query=type:song+gen:alauda'
]

dataset_path = 'dataset'

for url in urls:
    response = requests.get(url)
    response.raise_for_status()
    data = response.json()
    
    if data['recordings']:
        genus = data['recordings'][0]['gen'].lower()
        genus_path = os.path.join(dataset_path, genus)
        
        for recording in data['recordings'][:300]:  # Limite à 300 enregistrements pour diminuer le temps de traitement
            audio_url = recording['file']
            filename = sanitize_filename(recording['file-name'])
            filepath = os.path.join(genus_path, filename)
            download_file(audio_url, filepath)
# Out:
# Downloading from https://xeno-canto.org/672086/download to dataset\emberiza\XC672086-bunting song[ExtAudio].mp3...
# Downloading from https://xeno-canto.org/652967/download to dataset\emberiza\XC652967-crested bunting 20210530-100646.mp3...
# Downloading from https://xeno-canto.org/796619/download to dataset\emberiza\XC796619-CrestedBunting_MuangNgan_230421_2087_edited.mp3...
# Downloading from https://xeno-canto.org/796618/download to dataset\emberiza\XC796618-CrestedBunting_MuangNgan_230421_2085_edited.mp3...
# Downloading from https://xeno-canto.org/481292/download to dataset\emberiza\XC481292-crbu_may2019_C0004a.mp3...
# Downloading from https://xeno-canto.org/472696/download to dataset\emberiza\XC472696-LS101479 Crested Bunting song B.mp3...
# Downloading from https://xeno-canto.org/463615/download to dataset\emberiza\XC463615-2060 CRESTED BUNTING 18.mp3...
# Downloading from https://xeno-canto.org/177703/download to dataset\emberiza\XC177703-Crested-Bunting-Mishmi-Hills-May3-2014-Pritam-Baruah.mp3...
# Downloading from https://xeno-canto.org/138751/download to dataset\emberiza\XC138751-crested bunting x 130522.mp3...
# Downloading from https://xeno-canto.org/100909/download to dataset\emberiza\Melophus_lathami-FL male song nr Dirang 21Apr12 LS110470.mp3...
# Downloading from https://xeno-canto.org/19650/download to dataset\emberiza\crestedbuntingsongbhutanFarrow.mp3...
# Downloading from https://xeno-canto.org/742632/download to dataset\emberiza\XC742632-20220725-广西武宣土番大山-凤头鹀-song-071606.mp3...
# Downloading from https://xeno-canto.org/467428/download to dataset\emberiza\XC467428-190415_0238_CrestedBunting.mp3...
# Downloading from https://xeno-canto.org/317268/download to dataset\emberiza\XC317268-Crested Bunting.mp3...
# Downloading from https://xeno-canto.org/81113/download to dataset\emberiza\CrestedBuntingSong110411-006ChinaGuangxiShanli.mp3...
# Downloading from https://xeno-canto.org/157796/download to dataset\emberiza\XC157796-Melophus_lathami-FL song nr Roing Mishmi Arunachal Pradesh c650m 13Apr13 LS114212.mp3...
# Downloading from https://xeno-canto.org/804351/download to dataset\emberiza\XC804351-Slaty-Bunting蓝鹀-song-2105150533-ntg-神农架-神农酒店SHADOW_2251S12.mp3...
# Downloading from https://xeno-canto.org/768749/download to dataset\emberiza\XC768749-song-2-西岭雪山.mp3...
# Downloading from https://xeno-canto.org/768723/download to dataset\emberiza\XC768723-song-3-卧龙喇嘛寺.mp3...
# Downloading from https://xeno-canto.org/657214/download to dataset\emberiza\XC657214-Emberiza siemsseni T1810 cut edit 1200 bandstop.mp3...
# Downloading from https://xeno-canto.org/652390/download to dataset\emberiza\XC652390- song 2105140618 ntg 神农架 神农酒店SHADOW_2231S12.mp3...
# Downloading from https://xeno-canto.org/304208/download to dataset\emberiza\XC304208-Slaty Bunting_Longwangshan, Anji_20130414_LS110207.mp3...
# Downloading from https://xeno-canto.org/265930/download to dataset\emberiza\XC265930-Slaty Bunting1FP2015.mp3...
# Downloading from https://xeno-canto.org/81238/download to dataset\emberiza\SlatyBunting(Latoucheornissiemsseni)song100525-008ChinaHunanHuPingShanJM.mp3...
# Downloading from https://xeno-canto.org/81237/download to dataset\emberiza\SlatyBunting(Latoucheornissiemsseni)song100525-007ChinaHunanHuPingShanJM.mp3...
# Downloading from https://xeno-canto.org/68557/download to dataset\emberiza\Latoucheornis_siemsseni_Sichuan-99a-FRL_CN_34_2151-2207_1_S.mp3...
# Downloading from https://xeno-canto.org/18639/download to dataset\emberiza\HI-0503-Slaty-Bunting.mp3...
# Downloading from https://xeno-canto.org/768748/download to dataset\emberiza\XC768748-call,-song-西岭雪山.mp3...
# Downloading from https://xeno-canto.org/768722/download to dataset\emberiza\XC768722-song-2-卧龙喇嘛寺.mp3...
# Downloading from https://xeno-canto.org/768721/download to dataset\emberiza\XC768721-song-1-卧龙喇嘛寺.mp3...
# Downloading from https://xeno-canto.org/896618/download to dataset\emberiza\XC896618-04-11-2024_20h49_bruant-proyer.wav...
# Downloading from https://xeno-canto.org/896500/download to dataset\emberiza\XC896500-04-11-2024_20h13_bruant-proyer.wav...
# Downloading from https://xeno-canto.org/895450/download to dataset\emberiza\XC895450-Embcal_Riofrio_240404.wav...
# Downloading from https://xeno-canto.org/882055/download to dataset\emberiza\XC882055-Emberiza-calandra_song_150324_Baltanás.wav...
# Downloading from https://xeno-canto.org/879369/download to dataset\emberiza\XC879369-JAREK-MATUSIAK-A-2080-potrzeszcz.mp3...
# Downloading from https://xeno-canto.org/879165/download to dataset\emberiza\XC879165-010420Grauammer_Tadten_DPA4060_44100.wav...
# Downloading from https://xeno-canto.org/877568/download to dataset\emberiza\XC877568-MixPre-006_Emberiza_calandra_.wav...
# Downloading from https://xeno-canto.org/876872/download to dataset\emberiza\XC876872-Emberiza-calandra_song_200224_Fuentes-de-los-Oteros.wav...
# Downloading from https://xeno-canto.org/871433/download to dataset\emberiza\XC871433-Bruant-proyer-Mekseh-Liban.wav...
# Downloading from https://xeno-canto.org/864606/download to dataset\emberiza\XC864606-MILCAL_chant_240114_Andalousie.mp3...
# Downloading from https://xeno-canto.org/864393/download to dataset\emberiza\XC864393-21042023_026_KORNSPURV-bieter-ELHORCAJO-SPANIA-TELINGA-16BIT.wav...
# Downloading from https://xeno-canto.org/861727/download to dataset\emberiza\XC861727-MILCAL140623a.wav...
# Downloading from https://xeno-canto.org/860939/download to dataset\emberiza\XC860939-proyer-best-of-the-best.mp3...
# Downloading from https://xeno-canto.org/857579/download to dataset\emberiza\XC857579-emberiza-calandra-cortijo-grande-26-05-2022.mp3...
# Downloading from https://xeno-canto.org/845584/download to dataset\emberiza\XC845584-1021.wav...
# Downloading from https://xeno-canto.org/845580/download to dataset\emberiza\XC845580-1019.wav...
# Downloading from https://xeno-canto.org/845579/download to dataset\emberiza\XC845579-1018_Song.wav...
# Downloading from https://xeno-canto.org/845578/download to dataset\emberiza\XC845578-1018_Song.wav...
# Downloading from https://xeno-canto.org/845576/download to dataset\emberiza\XC845576-1016_Song.wav...
# Downloading from https://xeno-canto.org/845568/download to dataset\emberiza\XC845568-1014.wav...
# Downloading from https://xeno-canto.org/845567/download to dataset\emberiza\XC845567-1013_Song.wav...
# Downloading from https://xeno-canto.org/845562/download to dataset\emberiza\XC845562-1012.wav...
# Downloading from https://xeno-canto.org/845549/download to dataset\emberiza\XC845549-1011.wav...
# Downloading from https://xeno-canto.org/845546/download to dataset\emberiza\XC845546-1010.wav...
# Downloading from https://xeno-canto.org/845541/download to dataset\emberiza\XC845541-1007.wav...
# Downloading from https://xeno-canto.org/845187/download to dataset\emberiza\XC845187-EMBCAL-Gacholle-22052023.wav...
# Downloading from https://xeno-canto.org/842345/download to dataset\emberiza\XC842345-BRP4_song_male_23062023.wav...
# Downloading from https://xeno-canto.org/841517/download to dataset\emberiza\XC841517-230526-MP-1877-10h49-id-bruant-proyer.mp3...
# Downloading from https://xeno-canto.org/840058/download to dataset\emberiza\XC840058-230613_001_9.00_M.cal.mp3...
# Downloading from https://xeno-canto.org/839406/download to dataset\emberiza\XC839406-Bruantproyer_24042023_ferrièreslesverreries_11h-chant.mp3...
# Downloading from https://xeno-canto.org/836270/download to dataset\emberiza\XC836270-emberiza-calandra-guadiatillo-10-05-2022.mp3...
# Downloading from https://xeno-canto.org/835054/download to dataset\emberiza\XC835054-emberiza-calandra-cortijo-chico-20-05-2019.mp3...
# Downloading from https://xeno-canto.org/834400/download to dataset\emberiza\XC834400-emberiza-calandra-5-las-ventillas-17-04-2018.mp3...
# Downloading from https://xeno-canto.org/834399/download to dataset\emberiza\XC834399-emberiza-calandra-4-las-ventillas-17-04-2018.mp3...
# Downloading from https://xeno-canto.org/834397/download to dataset\emberiza\XC834397-emberiza-calandra-3-las-ventillas-17-04-2018.mp3...
# Downloading from https://xeno-canto.org/834396/download to dataset\emberiza\XC834396-emberiza-calandra-2-las-ventillas-17-04-2018.mp3...
# Downloading from https://xeno-canto.org/834395/download to dataset\emberiza\XC834395-emberiza-calandra-1-las-ventillas-17-04-2018.mp3...
# Downloading from https://xeno-canto.org/826952/download to dataset\emberiza\XC826952-230608-003_proyer-etourneaux_cut.wav...
# Downloading from https://xeno-canto.org/819190/download to dataset\emberiza\XC819190-23.005.2023---19.12---E.calandra.wav...
# Downloading from https://xeno-canto.org/818589/download to dataset\emberiza\XC818589-Bruant_proyer_Emberiza_calandra_song_Valensole.wav...
# Downloading from https://xeno-canto.org/815959/download to dataset\emberiza\XC815959-230531_04_Corn-Bunting_Unteres-Odertal-National-Park,-Brandenberg,-Germany_31-May-2023.wav...
# Downloading from https://xeno-canto.org/810269/download to dataset\emberiza\XC810269-230502_1762-1809-Grauammer.-Lesvos.-Skala-Kallonis.-Stephan-Risch.wav...
# Downloading from https://xeno-canto.org/810240/download to dataset\emberiza\XC810240-Default_20230607-kornsparv.mp3...
# Downloading from https://xeno-canto.org/810183/download to dataset\emberiza\XC810183-230502_1726-0924-Grauammer.-Skala-Kallonis.-Lower-Tsiknias-River.-Stephan-Risch.wav...
# Downloading from https://xeno-canto.org/809319/download to dataset\emberiza\XC809319-230611_12Emberiza-calandra-boa-10.00-Fervenza,-Brandomil.mp3...
# Downloading from https://xeno-canto.org/807725/download to dataset\emberiza\XC807725-210617_3979-1010-Grauammer.-D,-BB,-UM,-Polder-nahe-Stolpe.wav...
# Downloading from https://xeno-canto.org/807566/download to dataset\emberiza\XC807566-230526_2019-0959-Grauammer.-D,-BB,-UM,-Polder-nahe-Stolpe.-Stephan-Risch.wav...
# Downloading from https://xeno-canto.org/807524/download to dataset\emberiza\XC807524-Corn-Bunting-1.mp3...
# Downloading from https://xeno-canto.org/807360/download to dataset\emberiza\XC807360-20230603_1030_Corn-Bunting_Heuzugwiesen-Schwedt_song.mp3...
# Downloading from https://xeno-canto.org/807293/download to dataset\emberiza\XC807293-230526_2063-1223-Grauammer.-D,-BB,-UM.-Polder-nahe-Criewen,-Stephan-Risch.wav...
# Downloading from https://xeno-canto.org/806376/download to dataset\emberiza\XC806376-Kornsparv-2023-05-24.mp3...
# Downloading from https://xeno-canto.org/805857/download to dataset\emberiza\XC805857-230531_105801_01.mp3...
# Downloading from https://xeno-canto.org/805769/download to dataset\emberiza\XC805769-Emberiza-calandra_2023.05.31_11.51_11.mp3...
# Downloading from https://xeno-canto.org/805374/download to dataset\emberiza\XC805374-230524_1937-1229-Grauammer.-D,-BB,-Garlitz.-Weg-zum-Beobachtungsturm.-Stephan-Risch.wav...
# Downloading from https://xeno-canto.org/804541/download to dataset\emberiza\XC804541-Grauwe-gors-230518-Vardzia-1.mp3...
# Downloading from https://xeno-canto.org/803590/download to dataset\emberiza\XC803590-Corn-Bunting,-Bellavista-Farm,-20230524.mp3...
# Downloading from https://xeno-canto.org/802604/download to dataset\emberiza\XC802604-2023.05.18_15.11_21.mp3...
# Downloading from https://xeno-canto.org/802602/download to dataset\emberiza\XC802602-Emberiza-calandra2023.05.18_15.08_11.mp3...
# Downloading from https://xeno-canto.org/802598/download to dataset\emberiza\XC802598-2023.05.18_15.06_01.mp3...
# Downloading from https://xeno-canto.org/802593/download to dataset\emberiza\XC802593-Emberiza-calandra_2023.05.20_11.59_21.mp3...
# Downloading from https://xeno-canto.org/802592/download to dataset\emberiza\XC802592-Emberiza-calandra_2023.05.20_12.39_31.mp3...
# Downloading from https://xeno-canto.org/801895/download to dataset\emberiza\XC801895-Emberiza-calandra_Delta_2231.wav...
# Downloading from https://xeno-canto.org/801893/download to dataset\emberiza\XC801893-Emberiza-calandra_Delta_2230.wav...
# Downloading from https://xeno-canto.org/800751/download to dataset\emberiza\XC800751-Enberiza-calandra2023.05.12_10.21_01.mp3...
# Downloading from https://xeno-canto.org/800749/download to dataset\emberiza\XC800749-2023.05.12_11.21_01.mp3...
# Downloading from https://xeno-canto.org/800003/download to dataset\emberiza\XC800003-Buant-proyer-pliks-puis-chants-+.wav...
# Downloading from https://xeno-canto.org/799561/download to dataset\emberiza\XC799561-230501_03Emberiza-calandra-8.30-Caque,-CRde-Lea.mp3...
# Downloading from https://xeno-canto.org/799349/download to dataset\emberiza\XC799349-Corn-Bunt01.mp3...
# Downloading from https://xeno-canto.org/799272/download to dataset\emberiza\XC799272-2023.05.08_11.02_40.mp3...
# Downloading from https://xeno-canto.org/799271/download to dataset\emberiza\XC799271-2023.05.08_10.42_92.mp3...
# Downloading from https://xeno-canto.org/799270/download to dataset\emberiza\XC799270-Emberiza-calandra_2023.05.08_10.33_41.mp3...
# Downloading from https://xeno-canto.org/799269/download to dataset\emberiza\XC799269-2023.05.08_10.29_02.mp3...
# Downloading from https://xeno-canto.org/799267/download to dataset\emberiza\XC799267-Emberiza-calandra_2023.05.08_10.26_11.mp3...
# Downloading from https://xeno-canto.org/799263/download to dataset\emberiza\XC799263-Emberiza-calandra_2023.05.08_10.22_01.mp3...
# Downloading from https://xeno-canto.org/797812/download to dataset\emberiza\XC797812-Emberiza-calandra_SONG_Argany_230502_1011.wav...
# Downloading from https://xeno-canto.org/797512/download to dataset\emberiza\XC797512-ARLES-Capeliere_Bruant-Proyer_210529_14h.wav...
# Downloading from https://xeno-canto.org/796466/download to dataset\emberiza\XC796466-230428_004_0830_Ervedal_Corn-Buting_SNPZTr2.wav...
# Downloading from https://xeno-canto.org/795370/download to dataset\emberiza\XC795370-2023-04-22-10.08.07.wav...
# Downloading from https://xeno-canto.org/795136/download to dataset\emberiza\XC795136-Escribano-triguero.wav...
# Downloading from https://xeno-canto.org/793801/download to dataset\emberiza\XC793801-Emb-cal-Palencia.mp3...
# Downloading from https://xeno-canto.org/791550/download to dataset\emberiza\XC791550-grauamm0638.mp3...
# Downloading from https://xeno-canto.org/791531/download to dataset\emberiza\XC791531-cornbun2t.wav...
# Downloading from https://xeno-canto.org/791530/download to dataset\emberiza\XC791530-cornbun3t.wav...
# Downloading from https://xeno-canto.org/791529/download to dataset\emberiza\XC791529-cornbunt.wav...
# Downloading from https://xeno-canto.org/789668/download to dataset\emberiza\XC789668-Emb.cal.1_Cabo-Espichel.wav...
# Downloading from https://xeno-canto.org/789549/download to dataset\emberiza\XC789549-2022_maart_31_grauwegors_0929hrs_Villafafila_GOKeijl.mp3...
# Downloading from https://xeno-canto.org/787601/download to dataset\emberiza\XC787601-Emberiza-calandra_song_22_03_23_Olmillos-de-Castro.wav...
# Downloading from https://xeno-canto.org/787108/download to dataset\emberiza\XC787108-ecalandra_230319_djazero.wav...
# Downloading from https://xeno-canto.org/786650/download to dataset\emberiza\XC786650-Emberiza-calandra_CALL_SONG_Argany_230319_1038.wav...
# Downloading from https://xeno-canto.org/785961/download to dataset\emberiza\XC785961-JAREK-MATUSIAK-1695-potrzeszcz.mp3...
# Downloading from https://xeno-canto.org/785917/download to dataset\emberiza\XC785917-Emberiza-calandra_song_14_03_23_Barruecopardo.wav...
# Downloading from https://xeno-canto.org/784936/download to dataset\emberiza\XC784936-Emberiza-calandra_song_09_03_23_Perilla-de-Castro.wav...
# Downloading from https://xeno-canto.org/784426/download to dataset\emberiza\XC784426-Emberiza-calandra-(Tenerife)---Los-Rodeos-(La-Laguna).mp3...
# Downloading from https://xeno-canto.org/782640/download to dataset\emberiza\XC782640-230217_10Emberiza-calandra-cable-luz-Otero-9.00-Villafáfila.mp3...
# Downloading from https://xeno-canto.org/782227/download to dataset\emberiza\XC782227-23-02-23-(bruant-proyer,-chant,-Laar-4,-beau).wav...
# Downloading from https://xeno-canto.org/782105/download to dataset\emberiza\XC782105-ecalandra2_230222_djazero.wav...
# Downloading from https://xeno-canto.org/775833/download to dataset\emberiza\XC775833-MIXPRE-064.wav...
# Downloading from https://xeno-canto.org/770884/download to dataset\emberiza\XC770884-Corn-Bunting,-song,-221222-004_094128.wav...
# Downloading from https://xeno-canto.org/759819/download to dataset\emberiza\XC759819-Grauwe-Gors-20220521-1610-1a.mp3...
# Downloading from https://xeno-canto.org/759818/download to dataset\emberiza\XC759818-Grauwe-Gors-20220521-1600-2a.mp3...
# Downloading from https://xeno-canto.org/759816/download to dataset\emberiza\XC759816-Grauwe-Gors-20220521-1600-1a.mp3...
# Downloading from https://xeno-canto.org/757548/download to dataset\emberiza\XC757548-GraummerMaleSong_Wauwilermoos_BirkeOst.mp3...
# Downloading from https://xeno-canto.org/744206/download to dataset\emberiza\XC744206-220707_2751-7.10_Em.calandra_Szczytna.mp3...
# Downloading from https://xeno-canto.org/744205/download to dataset\emberiza\XC744205-220707_2750-7.05_Em.calandra_Szczytna.mp3...
# Downloading from https://xeno-canto.org/744187/download to dataset\emberiza\XC744187-220626_2732-21.10_Em.calandra-śp.mp3...
# Downloading from https://xeno-canto.org/741757/download to dataset\emberiza\XC741757-Emberiza calandra Corn Bunting song 2022-05-07 1010 Bessaparski Hills, Pazardzhik 42.12760, 24.41813 (seen) ME66-D100.mp3...
# Downloading from https://xeno-canto.org/741756/download to dataset\emberiza\XC741756-Emberiza calandra Corn Bunting song 2022-05-05 0807 Bessaparski Hills, Pazardzhik 42.09840, 24.44468 (seen) ME66-D100.mp3...
# Downloading from https://xeno-canto.org/741754/download to dataset\emberiza\XC741754-Emberiza calandra Corn Bunting song 2022-05-05 1007 Bessaparski Hills, Pazardzhik 42.10580, 24.45056 (seen) ME66-D100.mp3...
# Downloading from https://xeno-canto.org/740562/download to dataset\emberiza\XC740562-220728_0024_Kornsparv sång 2EDIT.mp3...
# Downloading from https://xeno-canto.org/740161/download to dataset\emberiza\XC740161-kornsparv sång.mp3...
# Downloading from https://xeno-canto.org/736736/download to dataset\emberiza\XC736736-CornBunting(Singing),DurdleDoor,Dorset.08.07.2022(0815).mp3...
# Downloading from https://xeno-canto.org/733717/download to dataset\emberiza\XC733717-potrzeszcz śpiew 220422_Książ Wielki.mp3...
# Downloading from https://xeno-canto.org/732556/download to dataset\emberiza\XC732556-220617_01Emberiza calandra 3.30 Xestoso, Silleda.mp3...
# Downloading from https://xeno-canto.org/729733/download to dataset\emberiza\XC729733-graua0448.mp3...
# Downloading from https://xeno-canto.org/729694/download to dataset\emberiza\XC729694-emberiza_calandra_krywlany_bialystok_podlaskie_2022.06.06_2105.mp3...
# Downloading from https://xeno-canto.org/726963/download to dataset\emberiza\XC726963-Strillozzo song_0522_0918.mp3...
# Downloading from https://xeno-canto.org/726460/download to dataset\emberiza\XC726460-CB-853007A.mp3...
# Downloading from https://xeno-canto.org/726333/download to dataset\emberiza\XC726333-220514_07Millaria e paspallás A Portela 9.00 Mandín, Verín.mp3...
# Downloading from https://xeno-canto.org/726330/download to dataset\emberiza\XC726330-220514_06Millaria calandra 9.00 A portela,   Mandín Verín.mp3...
# Downloading from https://xeno-canto.org/725784/download to dataset\emberiza\XC725784-220513_31 Milaria e paspallás, 18.00  Campos anexos Paseo Mourazos-Tamaguelos.mp3...
# Downloading from https://xeno-canto.org/724344/download to dataset\emberiza\XC724344-proyer-15h-15mai22-aveze.mp3...
# Downloading from https://xeno-canto.org/724323/download to dataset\emberiza\XC724323-220514_0527.mp3...
# Downloading from https://xeno-canto.org/724067/download to dataset\emberiza\XC724067-EMBCAL_220512_1951_Marcevol66.mp3...
# Downloading from https://xeno-canto.org/724065/download to dataset\emberiza\XC724065-EMBCAL_220511_1943_Marcevol66.mp3...
# Downloading from https://xeno-canto.org/724049/download to dataset\emberiza\XC724049-220514_001.mp3...
# Downloading from https://xeno-canto.org/723566/download to dataset\emberiza\XC723566-ecalandra_hajbrod_2022_05_10-15_28_14.mp3...
# Downloading from https://xeno-canto.org/722941/download to dataset\emberiza\XC722941-EMBCAL_220509_1902_Marcevol66_.mp3...
# Downloading from https://xeno-canto.org/722940/download to dataset\emberiza\XC722940-EMBCAL_220509_1901_Marcevol66_.mp3...
# Downloading from https://xeno-canto.org/722631/download to dataset\emberiza\XC722631-Voice 210.mp3...
# Downloading from https://xeno-canto.org/722323/download to dataset\emberiza\XC722323-Strillozzo song_0504_1626.mp3...
# Downloading from https://xeno-canto.org/719587/download to dataset\emberiza\XC719587-Strillozzo song_0425_1755.mp3...
# Downloading from https://xeno-canto.org/719585/download to dataset\emberiza\XC719585-Strillozzo song_0425_1751.mp3...
# Downloading from https://xeno-canto.org/717427/download to dataset\emberiza\XC717427-22042103Triguero.mp3...
# Downloading from https://xeno-canto.org/716157/download to dataset\emberiza\XC716157-220417_embcal_song_2.mp3...
# Downloading from https://xeno-canto.org/716129/download to dataset\emberiza\XC716129-220417_embcal_song_1.mp3...
# Downloading from https://xeno-canto.org/715849/download to dataset\emberiza\XC715849-Strillozzo song_0415_1854.mp3...
# Downloading from https://xeno-canto.org/715847/download to dataset\emberiza\XC715847-Strillozzo calls e Song_0415_1834.mp3...
# Downloading from https://xeno-canto.org/715777/download to dataset\emberiza\XC715777-Strillozzo song_0413_1833.mp3...
# Downloading from https://xeno-canto.org/715117/download to dataset\emberiza\XC715117-grauam0706.mp3...
# Downloading from https://xeno-canto.org/714245/download to dataset\emberiza\XC714245-RDB-176_2022-04-01_14h30_CornBunting.mp3...
# Downloading from https://xeno-canto.org/714050/download to dataset\emberiza\XC714050-20220401 korsnpurv extremadura.mp3...
# Downloading from https://xeno-canto.org/713575/download to dataset\emberiza\XC713575-220406_1094_Bruant proyer (chant)_Antezant-la-Chapelle (17).mp3...
# Downloading from https://xeno-canto.org/711359/download to dataset\emberiza\XC711359-Emberiza calandra_SONG_Argany_220327_1147.mp3...
# Downloading from https://xeno-canto.org/710246/download to dataset\emberiza\XC710246-20210522_Bruant_proyer_Plaine_de_Crau.mp3...
# Downloading from https://xeno-canto.org/709307/download to dataset\emberiza\XC709307-Strillozzi song_220318_0835.mp3...
# Downloading from https://xeno-canto.org/708613/download to dataset\emberiza\XC708613-grauammer0953.mp3...
# Downloading from https://xeno-canto.org/707698/download to dataset\emberiza\XC707698-Bruantproyer_020521_carollesplateau.mp3...
# Downloading from https://xeno-canto.org/706299/download to dataset\emberiza\XC706299-triguero.mp3...
# Downloading from https://xeno-canto.org/703776/download to dataset\emberiza\XC703776-Strillozzo song_0220_1713.mp3...
# Downloading from https://xeno-canto.org/702288/download to dataset\emberiza\XC702288-220211-114019trigueirao.mp3...
# Downloading from https://xeno-canto.org/702184/download to dataset\emberiza\XC702184-Strillozzo song_0213_1042.mp3...
# Downloading from https://xeno-canto.org/699860/download to dataset\emberiza\XC699860-d)01_Bru_proy.mp3...
# Downloading from https://xeno-canto.org/696775/download to dataset\emberiza\XC696775-Bomlærke (Emberiza calandra) Matr_20200714-2128 Sang.mp3...
# Downloading from https://xeno-canto.org/695697/download to dataset\emberiza\XC695697-(d) Chant_Bruant Proyer.mp3...
# Downloading from https://xeno-canto.org/690624/download to dataset\emberiza\XC690624-XC676693 - Bruant proyer - Emberiza calandra.mp3...
# Downloading from https://xeno-canto.org/686707/download to dataset\emberiza\XC686707-Strillozzo (salt, upup) (c magn sop).mp3...
# Downloading from https://xeno-canto.org/685929/download to dataset\emberiza\XC685929-103 - ZOOM0006_MN.mp3...
# Downloading from https://xeno-canto.org/683524/download to dataset\emberiza\XC683524-211030_1861 mp3 noise red.mp3...
# Downloading from https://xeno-canto.org/678202/download to dataset\emberiza\XC678202-velika strnadica jesenska.mp3...
# Downloading from https://xeno-canto.org/676693/download to dataset\emberiza\XC676693-BRUANT PROYER SL RCF PETIT BAGNAS 29 03 21 XC.mp3...
# Downloading from https://xeno-canto.org/672015/download to dataset\emberiza\XC672015-23.bez nazwy.mp3...
# Downloading from https://xeno-canto.org/669234/download to dataset\emberiza\XC669234-7.bez nazwy.mp32.mp3...
# Downloading from https://xeno-canto.org/669232/download to dataset\emberiza\XC669232-1.a.ZOOM0001.mp3...
# Downloading from https://xeno-canto.org/664849/download to dataset\emberiza\XC664849-henrykowo6.bez nazwy.mp3...
# Downloading from https://xeno-canto.org/664260/download to dataset\emberiza\XC664260-ZOOM0005.mp3...
# Downloading from https://xeno-canto.org/659480/download to dataset\emberiza\XC659480-CB-27a.mp3...
# Downloading from https://xeno-canto.org/658835/download to dataset\emberiza\XC658835-138694.mp3...
# Downloading from https://xeno-canto.org/657662/download to dataset\emberiza\XC657662-2.ZOOM000.mp3...
# Downloading from https://xeno-canto.org/657585/download to dataset\emberiza\XC657585-velika_strnadica.mp3...
# Downloading from https://xeno-canto.org/657240/download to dataset\emberiza\XC657240-graua0442.mp3...
# Downloading from https://xeno-canto.org/657061/download to dataset\emberiza\XC657061-Emberiza_calandra_A_ML_HP1000Hz12dB_210615_0443.mp3...
# Downloading from https://xeno-canto.org/655878/download to dataset\emberiza\XC655878-Grauammer.mp3...
# Downloading from https://xeno-canto.org/655719/download to dataset\emberiza\XC655719-210608_0827_Bruant proyer mâle chanteur et cris -les Hammeaux COUDRAY.mp3...
# Downloading from https://xeno-canto.org/655609/download to dataset\emberiza\XC655609-Grauammer_Garching_Laaaaauuuut.mp3...
# Downloading from https://xeno-canto.org/654527/download to dataset\emberiza\XC654527-210420-Bruant proyer@Crau.mp3...
# Downloading from https://xeno-canto.org/653673/download to dataset\emberiza\XC653673-210529_0817_Bruant proyer_Coudray (53).mp3...
# Downloading from https://xeno-canto.org/650751/download to dataset\emberiza\XC650751-210516_3489 1351 Grauammer. D, BB, Uckermark, NE Schwedt. Stephan Risch.mp3...
# Downloading from https://xeno-canto.org/650462/download to dataset\emberiza\XC650462-210517_3589 1343 Grauammer. D, BB, Havelland, N of Gülpe.mp3...
# Downloading from https://xeno-canto.org/650087/download to dataset\emberiza\XC650087-proyer.mp3...
# Downloading from https://xeno-canto.org/647433/download to dataset\emberiza\XC647433-EMBCAL010521-T004 (2).mp3...
# Downloading from https://xeno-canto.org/646187/download to dataset\emberiza\XC646187-138 - bruant proyer STE-008d.mp3...
# Downloading from https://xeno-canto.org/644816/download to dataset\emberiza\XC644816-Bruant proyer.mp3...
# Downloading from https://xeno-canto.org/641801/download to dataset\emberiza\XC641801-proyer1, jaune, alouette.mp3...
# Downloading from https://xeno-canto.org/641800/download to dataset\emberiza\XC641800-proyer (grisette).mp3...
# Downloading from https://xeno-canto.org/640544/download to dataset\emberiza\XC640544-Emberiza calandra_A_ML_HP1000Hz12dB_210418_0089.mp3...
# Downloading from https://xeno-canto.org/640248/download to dataset\emberiza\XC640248-MVI_3097.mp3...
# Downloading from https://xeno-canto.org/640247/download to dataset\emberiza\XC640247-MVI_3096.mp3...
# Downloading from https://xeno-canto.org/638054/download to dataset\emberiza\XC638054-Bruant proyer (3).mp3...
# Downloading from https://xeno-canto.org/638053/download to dataset\emberiza\XC638053-Bruant proyer (2).mp3...
# Downloading from https://xeno-canto.org/637705/download to dataset\emberiza\XC637705-LS_57450 Grauwe Gors song AA.mp3...
# Downloading from https://xeno-canto.org/637704/download to dataset\emberiza\XC637704-LS_57440 Grauwe Gors song AA.mp3...
# Downloading from https://xeno-canto.org/635654/download to dataset\emberiza\XC635654-calandra još bolji pjev (online-audio-converter.com).mp3...
# Downloading from https://xeno-canto.org/635122/download to dataset\emberiza\XC635122-210401_0436.mp3...
# Downloading from https://xeno-canto.org/633370/download to dataset\emberiza\XC633370-MVI_3041.mp3...
# Downloading from https://xeno-canto.org/633369/download to dataset\emberiza\XC633369-MVI_3037.mp3...
# Downloading from https://xeno-canto.org/633368/download to dataset\emberiza\XC633368-MVI_3036.mp3...
# Downloading from https://xeno-canto.org/633365/download to dataset\emberiza\XC633365-MVI_3031.mp3...
# Downloading from https://xeno-canto.org/632949/download to dataset\emberiza\XC632949-70 - STE-003 Bruant proyer.mp3...
# Downloading from https://xeno-canto.org/631754/download to dataset\emberiza\XC631754-Emberiza calandra Corn Bunting song 2009-05-09 1836 Rødby 54.681204, 11.381641 (seen) Telinga 5W.mp3...
# Downloading from https://xeno-canto.org/625659/download to dataset\emberiza\XC625659-210226-001_HP03N6_12h03_Ecalandra.mp3...
# Downloading from https://xeno-canto.org/624761/download to dataset\emberiza\XC624761-210223-180132trigueirao.mp3...
# Downloading from https://xeno-canto.org/624759/download to dataset\emberiza\XC624759-210223-180103trigueirao.mp3...
# Downloading from https://xeno-canto.org/622146/download to dataset\emberiza\XC622146-21021707TrigueroMP3.mp3...
# Downloading from https://xeno-canto.org/620893/download to dataset\emberiza\XC620893-473-263941-6925 (1).mp3...
# Downloading from https://xeno-canto.org/620069/download to dataset\emberiza\XC620069-MIXPRE-3999.mp3...
# Downloading from https://xeno-canto.org/620063/download to dataset\emberiza\XC620063-MIXPRE-3996.mp3...
# Downloading from https://xeno-canto.org/619042/download to dataset\emberiza\XC619042-MIXPRE-3943.mp3...
# Downloading from https://xeno-canto.org/619039/download to dataset\emberiza\XC619039-MIXPRE-3940.mp3...
# Downloading from https://xeno-canto.org/619038/download to dataset\emberiza\XC619038-MIXPRE-3939.mp3...
# Downloading from https://xeno-canto.org/618528/download to dataset\emberiza\XC618528-triguero1.mp3...
# Downloading from https://xeno-canto.org/618527/download to dataset\emberiza\XC618527-triguero.mp3...
# Downloading from https://xeno-canto.org/618206/download to dataset\emberiza\XC618206-MIXPRE-3972.mp3...
# Downloading from https://xeno-canto.org/615702/download to dataset\emberiza\XC615702-2102-1953054-5078.mp3...
# Downloading from https://xeno-canto.org/611033/download to dataset\emberiza\XC611033-SprosserBeiGutzkow_RdeWijs_13.mp3...
# Downloading from https://xeno-canto.org/610525/download to dataset\emberiza\XC610525-MIXPRE-3625.mp3...
# Downloading from https://xeno-canto.org/610519/download to dataset\emberiza\XC610519-MIXPRE-3627.mp3...
# Downloading from https://xeno-canto.org/610413/download to dataset\emberiza\XC610413-MIXPRE-3612.mp3...
# Downloading from https://xeno-canto.org/610412/download to dataset\emberiza\XC610412-MIXPRE-3611.mp3...
# Downloading from https://xeno-canto.org/610409/download to dataset\emberiza\XC610409-MIXPRE-3607.mp3...
# Downloading from https://xeno-canto.org/610408/download to dataset\emberiza\XC610408-MIXPRE-3605.mp3...
# Downloading from https://xeno-canto.org/610407/download to dataset\emberiza\XC610407-MIXPRE-3604.mp3...
# Downloading from https://xeno-canto.org/610343/download to dataset\emberiza\XC610343-grauammer0857.mp3...
# Downloading from https://xeno-canto.org/600952/download to dataset\emberiza\XC600952-Mil cal.mp3...
# Downloading from https://xeno-canto.org/596272/download to dataset\emberiza\XC596272-Cbtg-853001.mp3...
# Downloading from https://xeno-canto.org/575098/download to dataset\emberiza\XC575098-19062020_embcal_song_1.mp3...
# Downloading from https://xeno-canto.org/572991/download to dataset\emberiza\XC572991-200626_2477 1134 Grauammer. D, BB, S Schönwalde. Stephan Risch.mp3...
# Downloading from https://xeno-canto.org/570654/download to dataset\emberiza\XC570654-Corn Bunting (song, BE, Neerheylissem, 20jun2020, 1).mp3...
# Downloading from https://xeno-canto.org/570652/download to dataset\emberiza\XC570652-Corn Bunting (alarm call+song, BE, Neerheylissem, 20jun2020, 1).mp3...
# Downloading from https://xeno-canto.org/568429/download to dataset\emberiza\XC568429-200509_0824_Marshfield_CornBunting_mp3.mp3...
# Downloading from https://xeno-canto.org/568428/download to dataset\emberiza\XC568428-200509_0820_Marshfield_CornBunting_mp3.mp3...
# Downloading from https://xeno-canto.org/568424/download to dataset\emberiza\XC568424-200509_0815_Marshfield_CornBunting_mp3.mp3...
# Downloading from https://xeno-canto.org/566179/download to dataset\emberiza\XC566179-200607_1616.mp3...
# Downloading from https://xeno-canto.org/565489/download to dataset\emberiza\XC565489-200602-165159trigueirao.mp3...
# Downloading from https://xeno-canto.org/565487/download to dataset\emberiza\XC565487-200602-164839trigueirao.mp3...
# Downloading from https://xeno-canto.org/565484/download to dataset\emberiza\XC565484-200602-164801trigueirao.mp3...
# Downloading from https://xeno-canto.org/565103/download to dataset\emberiza\XC565103-Embcal_3giugno2020_CassanoSpinola.mp3...
# Downloading from https://xeno-canto.org/564938/download to dataset\emberiza\XC564938-190603_0149.mp3...
# Downloading from https://xeno-canto.org/564594/download to dataset\emberiza\XC564594-0526_203816.mp3...
# Downloading from https://xeno-canto.org/562542/download to dataset\emberiza\XC562542-CornBunting200525_0507.mp3...
# Downloading from https://xeno-canto.org/562392/download to dataset\emberiza\XC562392-2020-05-26_Grauammer.mp3...
# Downloading from https://xeno-canto.org/559756/download to dataset\emberiza\XC559756-MVI_2062.mp3...
# Downloading from https://xeno-canto.org/559746/download to dataset\emberiza\XC559746-MVI_2044.mp3...
# Downloading from https://xeno-canto.org/559731/download to dataset\emberiza\XC559731-MVI_2028.mp3...
# Downloading from https://xeno-canto.org/558294/download to dataset\emberiza\XC558294-potrzeszcz Wilkowyje 14.05.2020  18.36.mp3...
# Downloading from https://xeno-canto.org/557045/download to dataset\emberiza\XC557045-05h24_proyer pour XC.mp3...
# Downloading from https://xeno-canto.org/557032/download to dataset\emberiza\XC557032-19h13_proyer pour XC.mp3...
# Downloading from https://xeno-canto.org/556987/download to dataset\emberiza\XC556987-200510_0805Grauammer.mp3...
# Downloading from https://xeno-canto.org/556985/download to dataset\emberiza\XC556985-200510_0804Grauammer.mp3...
# Downloading from https://xeno-canto.org/556983/download to dataset\emberiza\XC556983-200510_0803Grauammer2.mp3...
# Downloading from https://xeno-canto.org/556980/download to dataset\emberiza\XC556980-200510_0803Grauammer.mp3...
# Downloading from https://xeno-canto.org/556979/download to dataset\emberiza\XC556979-200510_0801Grauammer.mp3...
# Downloading from https://xeno-canto.org/556978/download to dataset\emberiza\XC556978-200510_0799GrauAmmerXC.mp3...
# Downloading from https://xeno-canto.org/556972/download to dataset\emberiza\XC556972-200510_0799Grauammer2.mp3...
# Downloading from https://xeno-canto.org/556796/download to dataset\emberiza\XC556796-Bruant proyer chant ++.mp3...
# Downloading from https://xeno-canto.org/556048/download to dataset\emberiza\XC556048-9 may. 8.36  triguero - ruiseñor.mp3...
# Downloading from https://xeno-canto.org/555197/download to dataset\emberiza\XC555197-Bruant_proyer190411_0043.mp3...
# Downloading from https://xeno-canto.org/554670/download to dataset\emberiza\XC554670-6 may. 9.01 triguero.mp3...
# Downloading from https://xeno-canto.org/554659/download to dataset\emberiza\XC554659-4 may. 8.57 escribano triguero-cogijada comun.mp3...
# Downloading from https://xeno-canto.org/554546/download to dataset\emberiza\XC554546-200505-164730 Bruant proyer chant.mp3...
# Downloading from https://xeno-canto.org/554112/download to dataset\emberiza\XC554112-Corn Bunting 20190521.mp3...
# Downloading from https://xeno-canto.org/553796/download to dataset\emberiza\XC553796-2020_05_02_Gray_bunting_Grauammer.mp3...
# Downloading from https://xeno-canto.org/552808/download to dataset\emberiza\XC552808-Bruant proyer cris 2 27042020 - La Verdière.mp3...
# Downloading from https://xeno-canto.org/551917/download to dataset\emberiza\XC551917-Tarla çintesi.mp3...
# Downloading from https://xeno-canto.org/551912/download to dataset\emberiza\XC551912-Bruant proyer chant halte migratoire 13042019 - Hyeres.mp3...
# Downloading from https://xeno-canto.org/548900/download to dataset\emberiza\XC548900-MVI_1684.mp3...
# Downloading from https://xeno-canto.org/548899/download to dataset\emberiza\XC548899-MVI_1683.mp3...
# Downloading from https://xeno-canto.org/548895/download to dataset\emberiza\XC548895-MVI_1680.mp3...
# Downloading from https://xeno-canto.org/540214/download to dataset\emberiza\XC540214-Emberiza calandra.mp3...
# Downloading from https://xeno-canto.org/536314/download to dataset\emberiza\XC536314-graua0952.mp3...
# Downloading from https://xeno-canto.org/535407/download to dataset\emberiza\XC535407-Bruant proyer chant +.mp3...
# Downloading from https://xeno-canto.org/877767/download to dataset\muscicapa\XC877767-20170531-Grauwe-vliegenvanger-Haamstede-Gadra-Maarten-Sluijter.mp3...
# Downloading from https://xeno-canto.org/863406/download to dataset\muscicapa\XC863406-MS_TX_KT_A_CU_SA_CP_PE_PJ_Z_TM_GR_Kodade_Estonia_180509_04.mp3...
# Downloading from https://xeno-canto.org/855056/download to dataset\muscicapa\XC855056-MUSSTR_230801_Crosagny.mp3...
# Downloading from https://xeno-canto.org/840542/download to dataset\muscicapa\XC840542-grauwe-vliegenvanger_aud_zodden9.wav...
# Downloading from https://xeno-canto.org/809233/download to dataset\muscicapa\XC809233-GRAUSCHNÄPPER-6_22--Murn.-Moos-VOC_230606-4246+7g.wav...
# Downloading from https://xeno-canto.org/807984/download to dataset\muscicapa\XC807984-Muscicapa-striata-230526_002,AA-song.mp3...
# Downloading from https://xeno-canto.org/807983/download to dataset\muscicapa\XC807983-Muscicapa-striata-230526_002,A-song.mp3...
# Downloading from https://xeno-canto.org/806435/download to dataset\muscicapa\XC806435-Pigliamosche.mp3...
# Downloading from https://xeno-canto.org/805270/download to dataset\muscicapa\XC805270-MUSSTR-PALUP6HJA-230528_5275.mp3...
# Downloading from https://xeno-canto.org/804416/download to dataset\muscicapa\XC804416-grauschn0651.mp3...
# Downloading from https://xeno-canto.org/802883/download to dataset\muscicapa\XC802883-Grå-flugsnappare_18.mp3...
# Downloading from https://xeno-canto.org/801327/download to dataset\muscicapa\XC801327-13-05-23-(gobemouche-gris,-chant,-Lachaussée).wav...
# Downloading from https://xeno-canto.org/799674/download to dataset\muscicapa\XC799674-grauwe-vliegenvanger_aud_zodden5.wav...
# Downloading from https://xeno-canto.org/780925/download to dataset\muscicapa\XC780925-Grauwe-Vliegenvanger2.mp3...
# Downloading from https://xeno-canto.org/757022/download to dataset\muscicapa\XC757022-Spotted-Flycatcher_20200521_080955_prepared.mp3...
# Downloading from https://xeno-canto.org/751250/download to dataset\muscicapa\XC751250-Gobemouche gris.mp3...
# Downloading from https://xeno-canto.org/736870/download to dataset\muscicapa\XC736870-220515 07 57 14 LT 1891 Grauschnäpper Oberrotweil.mp3...
# Downloading from https://xeno-canto.org/733930/download to dataset\muscicapa\XC733930-grå_flugsnappare_20220612_0758_sång_Rönnbäck_Hissjö_AA_redigerad_202206.mp3...
# Downloading from https://xeno-canto.org/730613/download to dataset\muscicapa\XC730613-Gobemouchegris_110522_carollesparkinglude_8h05.mp3...
# Downloading from https://xeno-canto.org/730105/download to dataset\muscicapa\XC730105-d)00_GoMouGris.mp3...
# Downloading from https://xeno-canto.org/729616/download to dataset\muscicapa\XC729616-Spotted Flycatcher 060622.mp3...
# Downloading from https://xeno-canto.org/728632/download to dataset\muscicapa\XC728632-Muscicapa striata_2022.05.31_09.24_01.mp3...
# Downloading from https://xeno-canto.org/699128/download to dataset\muscicapa\XC699128-GrauweVliegenvangers_2_Wachtebeke_2021-06-08_0638_SC.mp3...
# Downloading from https://xeno-canto.org/688971/download to dataset\muscicapa\XC688971-xc-wa011107-000000.mp3...
# Downloading from https://xeno-canto.org/688970/download to dataset\muscicapa\XC688970-xc-wa011106-000007.mp3...
# Downloading from https://xeno-canto.org/688969/download to dataset\muscicapa\XC688969-xc-wa011099-000005.mp3...
# Downloading from https://xeno-canto.org/688968/download to dataset\muscicapa\XC688968-xc-wa011097-000042.mp3...
# Downloading from https://xeno-canto.org/672112/download to dataset\muscicapa\XC672112-2021.08.20_11.20_01.MP3...
# Downloading from https://xeno-canto.org/666681/download to dataset\muscicapa\XC666681-Spotted Flycatcher_Song_Coronation Plantation_260521_A+.mp3...
# Downloading from https://xeno-canto.org/666680/download to dataset\muscicapa\XC666680-Spotted Flycatcher_Song_Coronation Plantation_260521_A.mp3...
# Downloading from https://xeno-canto.org/666522/download to dataset\muscicapa\XC666522-grauwe_vliegenvanger_aud_zodden4.mp3...
# Downloading from https://xeno-canto.org/656551/download to dataset\muscicapa\XC656551-MUSSTR RAADI 210605_2985.mp3...
# Downloading from https://xeno-canto.org/654788/download to dataset\muscicapa\XC654788-Spotty Fly june 6.mp3...
# Downloading from https://xeno-canto.org/654787/download to dataset\muscicapa\XC654787-Spotted Fly song june 6.mp3...
# Downloading from https://xeno-canto.org/654786/download to dataset\muscicapa\XC654786-Spot Fly june 6.mp3...
# Downloading from https://xeno-canto.org/653471/download to dataset\muscicapa\XC653471-muharica pjev (online-audio-converter.com).mp3...
# Downloading from https://xeno-canto.org/653427/download to dataset\muscicapa\XC653427-MUSSTR Palup6hja 210530_2829.mp3...
# Downloading from https://xeno-canto.org/653425/download to dataset\muscicapa\XC653425-MUSSTR Palup6hja 210530_2825.mp3...
# Downloading from https://xeno-canto.org/652540/download to dataset\muscicapa\XC652540-muharica Osijek (online-audio-converter.com).mp3...
# Downloading from https://xeno-canto.org/650998/download to dataset\muscicapa\XC650998-grauwe vlieg.mp3...
# Downloading from https://xeno-canto.org/650938/download to dataset\muscicapa\XC650938-muchołówka szara Świerczyniec 23.05.2021   8.55.mp3...
# Downloading from https://xeno-canto.org/648930/download to dataset\muscicapa\XC648930-LS_57859 Grauwe Vliegenvanger song A.mp3...
# Downloading from https://xeno-canto.org/648929/download to dataset\muscicapa\XC648929-LS_57855 Grauwe Vliegenvanger song A.mp3...
# Downloading from https://xeno-canto.org/646977/download to dataset\muscicapa\XC646977-Muscicapa striata Spotted Flycatcher song 2006-07-02 0503 Penderi, Valles pagasts 56.486081, 24.780441 (seen) Telinga 5W.mp3...
# Downloading from https://xeno-canto.org/646764/download to dataset\muscicapa\XC646764-Muscicapa_striata.mp3...
# Downloading from https://xeno-canto.org/629491/download to dataset\muscicapa\XC629491-striata - northern Italy 25 may 2015 slow song _01_01.mp3...
# Downloading from https://xeno-canto.org/629490/download to dataset\muscicapa\XC629490-striata - northern Italy 18 may 2015 - fast song_01_01.mp3...
# Downloading from https://xeno-canto.org/611050/download to dataset\muscicapa\XC611050-ZangersOpTerschelling_8.mp3...
# Downloading from https://xeno-canto.org/598246/download to dataset\muscicapa\XC598246-Grauwe Vliegenvanger 20200609 1520 2a.mp3...
# Downloading from https://xeno-canto.org/598245/download to dataset\muscicapa\XC598245-Grauwe Vliegenvanger 20200609 1520 1a.mp3...
# Downloading from https://xeno-canto.org/598242/download to dataset\muscicapa\XC598242-Grauwe Vliegenvanger 20200609 1515 3a.mp3...
# Downloading from https://xeno-canto.org/598241/download to dataset\muscicapa\XC598241-Grauwe Vliegenvanger 20200609 1515 2a.mp3...
# Downloading from https://xeno-canto.org/598239/download to dataset\muscicapa\XC598239-Grauwe Vliegenvanger 20200609 1515 1a.mp3...
# Downloading from https://xeno-canto.org/577738/download to dataset\muscicapa\XC577738-Muscicapa striata 200709_001, AA song-call male.MP3...
# Downloading from https://xeno-canto.org/565442/download to dataset\muscicapa\XC565442-JAREK-MATUSIAK-520 muchołówka szara.mp3...
# Downloading from https://xeno-canto.org/562754/download to dataset\muscicapa\XC562754-200103_0022.mp3...
# Downloading from https://xeno-canto.org/560938/download to dataset\muscicapa\XC560938-Gobemouche gris chant + 2.mp3...
# Downloading from https://xeno-canto.org/560885/download to dataset\muscicapa\XC560885-Gobemouche gris chant 4.mp3...
# Downloading from https://xeno-canto.org/560882/download to dataset\muscicapa\XC560882-Gobemouche gris chant 2.mp3...
# Downloading from https://xeno-canto.org/560881/download to dataset\muscicapa\XC560881-Gobemouche gris chant et un cri en vol 5.mp3...
# Downloading from https://xeno-canto.org/560879/download to dataset\muscicapa\XC560879-Gobemouche gris chant ++.mp3...
# Downloading from https://xeno-canto.org/560878/download to dataset\muscicapa\XC560878-Gobemouche gris chant +.mp3...
# Downloading from https://xeno-canto.org/560877/download to dataset\muscicapa\XC560877-Gobemouche gris chant + 2.mp3...
# Downloading from https://xeno-canto.org/560347/download to dataset\muscicapa\XC560347-Gobemouche gris chant vol a la fin +.mp3...
# Downloading from https://xeno-canto.org/560345/download to dataset\muscicapa\XC560345-Gobemouche gris chant +.mp3...
# Downloading from https://xeno-canto.org/560343/download to dataset\muscicapa\XC560343-Gobemouche gris chant + 3.mp3...
# Downloading from https://xeno-canto.org/560342/download to dataset\muscicapa\XC560342-Gobemouche gris chant + 2.mp3...
# Downloading from https://xeno-canto.org/556930/download to dataset\muscicapa\XC556930-Gobemouche gris chant.mp3...
# Downloading from https://xeno-canto.org/483907/download to dataset\muscicapa\XC483907-grauschn0356.mp3...
# Downloading from https://xeno-canto.org/483834/download to dataset\muscicapa\XC483834-GRAUSCHNÄPPER, Gesang  26.06.2019  Ammersee S  8_22  VOC_190626-8127   Ausschn.   .mp3...
# Downloading from https://xeno-canto.org/483833/download to dataset\muscicapa\XC483833-GRAUSCHNÄPPER, Gesang  26.06.2019  Ammersee S  8_22  VOC_190626-8127   .mp3...
# Downloading from https://xeno-canto.org/481371/download to dataset\muscicapa\XC481371-Grauwe Vliegenvanger zang NHD 110617.mp3...
# Downloading from https://xeno-canto.org/481113/download to dataset\muscicapa\XC481113-MVI_0811.mp3...
# Downloading from https://xeno-canto.org/478984/download to dataset\muscicapa\XC478984-Grauwe Vliegenvanger, zang, Ten Boer, 010619, 1025 uur.mp3...
# Downloading from https://xeno-canto.org/475272/download to dataset\muscicapa\XC475272-Gobemouche gris chant ++.mp3...
# Downloading from https://xeno-canto.org/475270/download to dataset\muscicapa\XC475270-Gobemouche gris chant 2 +.mp3...
# Downloading from https://xeno-canto.org/475268/download to dataset\muscicapa\XC475268-Gobemouche gris chant 3 +.mp3...
# Downloading from https://xeno-canto.org/474906/download to dataset\muscicapa\XC474906-Grauwe vliegenvanger 190510 Kalmthoutse heide.mp3...
# Downloading from https://xeno-canto.org/423739/download to dataset\muscicapa\XC423739-LS_30467 20180518 09 26 Grauschnäpper.mp3...
# Downloading from https://xeno-canto.org/422685/download to dataset\muscicapa\XC422685-grauschn0408.mp3...
# Downloading from https://xeno-canto.org/422683/download to dataset\muscicapa\XC422683-grauschn0407.mp3...
# Downloading from https://xeno-canto.org/421584/download to dataset\muscicapa\XC421584-Grauschnäpper0413.mp3...
# Downloading from https://xeno-canto.org/421583/download to dataset\muscicapa\XC421583-Grauschn0411.mp3...
# Downloading from https://xeno-canto.org/401917/download to dataset\muscicapa\XC401917-Spotted flycatcher male song.mp3...
# Downloading from https://xeno-canto.org/397147/download to dataset\muscicapa\XC397147-GrauweVliegenvanger AkladeriForest160530_0140.mp3...
# Downloading from https://xeno-canto.org/380495/download to dataset\muscicapa\XC380495-Grauschnäpper.mp3...
# Downloading from https://xeno-canto.org/378437/download to dataset\muscicapa\XC378437-170526_0457-Muscicapa striata.mp3...
# Downloading from https://xeno-canto.org/374869/download to dataset\muscicapa\XC374869-rdb294_2017-06-05_06h08_Spotted_Flycatcher.mp3...
# Downloading from https://xeno-canto.org/374868/download to dataset\muscicapa\XC374868-rdb292_2017-06-05_06h04_Spotted_Flycatcher.mp3...
# ...
# Downloading from https://xeno-canto.org/896973/download to dataset\alaudala\XC896973-04-12-2024_9h49_alouette-des-champs.wav...
# Downloading from https://xeno-canto.org/896972/download to dataset\alaudala\XC896972-04-12-2024_9h34_alouette-des-champs.wav...
# Downloading from https://xeno-canto.org/896971/download to dataset\alaudala\XC896971-04-12-2024_9h26_alouette-des-champs.wav...
# Downloading from https://xeno-canto.org/896970/download to dataset\alaudala\XC896970-04-12-2024_9h17_alouette-des-champs.wav...
# Downloading from https://xeno-canto.org/896969/download to dataset\alaudala\XC896969-04-11-2024_19h29_alouette-des-champs.wav...
# Downloading from https://xeno-canto.org/895988/download to dataset\alaudala\XC895988-sånglärka_20240413_0820_sång_Kålsö_Mörkö_Srm_AA_redigerad_202404.mp3...
# Downloading from https://xeno-canto.org/895628/download to dataset\alaudala\XC895628-Alauda-arvensis-Eurasian-Skylark-song-2022-05-05-0816-Bessaparski-Hills-42.10011,-24.44429-(seen-not-id)-ME66-D100.wav...
# Downloading from https://xeno-canto.org/894564/download to dataset\alaudala\XC894564-Alouettedeschamps_Dourmidou_Goodsignal.wav...
# Downloading from https://xeno-canto.org/893507/download to dataset\alaudala\XC893507-alauda_arvensis_lipniki_podlaskie_2024.04.05_0814.mp3...
# Downloading from https://xeno-canto.org/890796/download to dataset\alaudala\XC890796-Sanglærke-(Alauda-arvensis)-Sdr-Lem-Vig_20240325-0936-sang.mp3...
# Downloading from https://xeno-canto.org/890391/download to dataset\alaudala\XC890391-ALAARV_220418_1616_Daviaud85_ChampFourny.mp3...
# Downloading from https://xeno-canto.org/890349/download to dataset\alaudala\XC890349-ALAARV_220421_1681_Daviaud85_PreduFour.mp3...
# Downloading from https://xeno-canto.org/884945/download to dataset\alaudala\XC884945-Skylark-song-24-Mar-23-Sand.mp3...
# Downloading from https://xeno-canto.org/884921/download to dataset\alaudala\XC884921-ALAARV_220418_1616_Daviaud85_ChampFourny.mp3...
# Downloading from https://xeno-canto.org/884756/download to dataset\alaudala\XC884756-ALAARV_230418_2693_DAVIAUD85_lim003.mp3...
# Downloading from https://xeno-canto.org/884753/download to dataset\alaudala\XC884753-ALAARV_230418_2710_DAVIAUD85_lim006.mp3...
# Downloading from https://xeno-canto.org/884752/download to dataset\alaudala\XC884752-ALAARV_230418_2669_DAVIAUD85_lim003.mp3...
# Downloading from https://xeno-canto.org/884750/download to dataset\alaudala\XC884750-ALAARV_230418_2634_DAVIAUD85_PreColas.mp3...
# Downloading from https://xeno-canto.org/883903/download to dataset\alaudala\XC883903-240317_003XC.mp3...
# Downloading from https://xeno-canto.org/883757/download to dataset\alaudala\XC883757-JAREK-MATUSIAK-A-2114-skowronek.mp3...
# Downloading from https://xeno-canto.org/883316/download to dataset\alaudala\XC883316-240319Alaudaarvensis_Grova.wav...
# Downloading from https://xeno-canto.org/881950/download to dataset\alaudala\XC881950-ALAARV_230419_2758_DAVIAUD85_lim009.mp3...
# Downloading from https://xeno-canto.org/881750/download to dataset\alaudala\XC881750-ALAARV_230421_2895_DAVIAUD85_Boissellerie.mp3...
# Downloading from https://xeno-canto.org/881733/download to dataset\alaudala\XC881733-ALAARV_230421_2916_DAVIAUD85_lim023.mp3...
# Downloading from https://xeno-canto.org/881703/download to dataset\alaudala\XC881703-ALAARV_230422_2972_DAVIAUD85_lim025_chant_sol.mp3...
# Downloading from https://xeno-canto.org/880678/download to dataset\alaudala\XC880678-ALAARV_230425_3100_Daviaud85_lim040.mp3...
# Downloading from https://xeno-canto.org/879423/download to dataset\alaudala\XC879423-ALAARV_chant_240305_Patures.mp3...
# Downloading from https://xeno-canto.org/878429/download to dataset\alaudala\XC878429-2024-02-28-1155-Skylark.wav...
# Downloading from https://xeno-canto.org/878211/download to dataset\alaudala\XC878211-FELDLERCHEN--16.02.2024--Kiesgrube-Th.--9_51-VOC_240216-4841.wav...
# Downloading from https://xeno-canto.org/878210/download to dataset\alaudala\XC878210-FELDLERCHEN-(3)--16.02.2024--Kiesgr.-Th.--9_55--VOC_240216-4842.wav...
# Downloading from https://xeno-canto.org/870846/download to dataset\alaudala\XC870846-Alouette-des-champs-230605-1200-1SA-France-Etang-Lachaussee.MixPre-4644.mp3...
# Downloading from https://xeno-canto.org/839837/download to dataset\alaudala\XC839837-230605_002_6.00_A.arven.mp3...
# Downloading from https://xeno-canto.org/833585/download to dataset\alaudala\XC833585-2023-06-01_17h28_alouette-des-champs.wav...
# Downloading from https://xeno-canto.org/822473/download to dataset\alaudala\XC822473-skylark-14_26_45.wav...
# Downloading from https://xeno-canto.org/812085/download to dataset\alaudala\XC812085-SKYLARK-St-Davids-Pembrokeshire-Wales-6.01am-06152022.wav...
# Downloading from https://xeno-canto.org/812082/download to dataset\alaudala\XC812082-SKYLARK-St-Davids-Pembrokeshire-Wales-5.58am-06152022.wav...
# Downloading from https://xeno-canto.org/812079/download to dataset\alaudala\XC812079-SKYLARK-St-Davids-Pembrokeshire-Wales-5.56am-06152022.wav...
# Downloading from https://xeno-canto.org/812078/download to dataset\alaudala\XC812078-SKYLARK-St-Davids-Pembrokeshire-Wales-5.48am-06152022.wav...
# Downloading from https://xeno-canto.org/812076/download to dataset\alaudala\XC812076-SKYLARK-St-Davids-Pembrokeshire-Wales-5.37am-06152022.wav...
# Downloading from https://xeno-canto.org/812075/download to dataset\alaudala\XC812075-SKYLARK-perched-St-Davids-Pembrokeshire-Wales-5.38am-06152022.wav...
# Downloading from https://xeno-canto.org/811774/download to dataset\alaudala\XC811774-XC---Alouette-des-champs-Tournan.wav...
# Downloading from https://xeno-canto.org/809567/download to dataset\alaudala\XC809567-Alouette_des_champs_20230618_0900_Marcilly_MixPre-Telinga_01_01.mp3...
# Downloading from https://xeno-canto.org/807544/download to dataset\alaudala\XC807544-230604_30laverca-frases-cortas-principio-suelo-luego-flight-song(1.06)-longo-13.00-Brandomil.mp3...
# Downloading from https://xeno-canto.org/806972/download to dataset\alaudala\XC806972-230604_06-Alauda-arvensis-song-11.30-Brandomil.mp3...
# Downloading from https://xeno-canto.org/806970/download to dataset\alaudala\XC806970-230604_03Alauda-arvensis-song-11.30-Fervenza,-Brandomil.mp3...
# Downloading from https://xeno-canto.org/804697/download to dataset\alaudala\XC804697-ALAARV-PIKLA-230512_5218.mp3...
# Downloading from https://xeno-canto.org/804394/download to dataset\alaudala\XC804394-Skylark,-Campo-Imperatore,-20230527.mp3...
# Downloading from https://xeno-canto.org/799352/download to dataset\alaudala\XC799352-Skylark-song02.mp3...
# Downloading from https://xeno-canto.org/799213/download to dataset\alaudala\XC799213-53.mp3...
# Downloading from https://xeno-canto.org/797659/download to dataset\alaudala\XC797659-Alouette_des_champs_Alauda_arvensis_song_Goulven.wav...
# Downloading from https://xeno-canto.org/796643/download to dataset\alaudala\XC796643-Veldleeuwerik-20220522-1650-1a.mp3...
# Downloading from https://xeno-canto.org/795732/download to dataset\alaudala\XC795732-Skylark-Sand-23-apr-0957.wav...
# Downloading from https://xeno-canto.org/795731/download to dataset\alaudala\XC795731-Skylark-Sand-23-apr-0620.wav...
# Downloading from https://xeno-canto.org/793619/download to dataset\alaudala\XC793619-Sånglärka_11.mp3...
# Downloading from https://xeno-canto.org/793394/download to dataset\alaudala\XC793394-Sånglärka-(Alauda-arvensis)-sång_Håslövs-ängar_2023-04-12_1400.mp3...
# Downloading from https://xeno-canto.org/793347/download to dataset\alaudala\XC793347-230410_08Alauda-arvensis-a-boa-song,-12.00-Quintás,-Lavacolla.mp3...
# Downloading from https://xeno-canto.org/791763/download to dataset\alaudala\XC791763-4.4.23-17.30-Alauda-arvensis--fly-song-17.30-Rodicio,Xunqueira.mp3...
# Downloading from https://xeno-canto.org/791762/download to dataset\alaudala\XC791762-4.4.23-17.00-Alauda-arvensis-vuelo-descenso-17.00-Rodicio,-Xunqueira-hpf1600.mp3...
# Downloading from https://xeno-canto.org/791761/download to dataset\alaudala\XC791761-230407_44Alauda-arvensis,-song-Dunas-de-Traba-15.00-HPF-1500.mp3...
# Downloading from https://xeno-canto.org/788196/download to dataset\alaudala\XC788196-20230325_142729-(mp3cut.net)-(1).mp3...
# Downloading from https://xeno-canto.org/787641/download to dataset\alaudala\XC787641-Alauda-arvensis_song_22_03_23_Máquiz-de-Alba_2.wav...
# Downloading from https://xeno-canto.org/786017/download to dataset\alaudala\XC786017-skylark.wav...
# Downloading from https://xeno-canto.org/785699/download to dataset\alaudala\XC785699-Alouette_des_champs_2022-04-14_11-05-28.mp3...
# Downloading from https://xeno-canto.org/784512/download to dataset\alaudala\XC784512-Allodole-(merlo)-c.magno-sop.mp3...
# Downloading from https://xeno-canto.org/784511/download to dataset\alaudala\XC784511-Allodola-(canto-volo)-c.alt.mp3...
# Downloading from https://xeno-canto.org/783541/download to dataset\alaudala\XC783541-230217_35Alauda-arvensis-vuelo-descendente-Puente-Romano-11.30-,-Villafáfila.mp3...
# Downloading from https://xeno-canto.org/782486/download to dataset\alaudala\XC782486-FELDLERCHEN--9_18--VOC_230224-3633-G.wav...
# Downloading from https://xeno-canto.org/780612/download to dataset\alaudala\XC780612-skylarksongdawntacfeb23.wav...
# Downloading from https://xeno-canto.org/777640/download to dataset\alaudala\XC777640-UID-Lark-song-2022-06-13-1947-Kurty-43.88111,-76.32497-(seen-not-id)-ME66-D100.wav...
# Downloading from https://xeno-canto.org/769232/download to dataset\alaudala\XC769232-Veldleeuwerik-zang---Hollum---2021-04-14---0845-copy.mp3...
# Downloading from https://xeno-canto.org/769230/download to dataset\alaudala\XC769230-Veldleeuwerik-zang---Hollum---2021-04-14---0833-copy.mp3...
# Downloading from https://xeno-canto.org/758509/download to dataset\alaudala\XC758509-xc-wa013651-000002.mp3...
# Downloading from https://xeno-canto.org/758503/download to dataset\alaudala\XC758503-xc-wa013648-000053.mp3...
# Downloading from https://xeno-canto.org/758165/download to dataset\alaudala\XC758165-xc-wa013395-000033.mp3...
# Downloading from https://xeno-canto.org/758101/download to dataset\alaudala\XC758101-xc-wa013387-000024.mp3...
# Downloading from https://xeno-canto.org/750184/download to dataset\alaudala\XC750184-Alouette_des_champs_chant_plaine_arrière_RNR_BEA_19h44_01_06_2022_for_XC.mp3...
# Downloading from https://xeno-canto.org/749168/download to dataset\alaudala\XC749168-220610 MP-1527 11h28 chant complet alouette des champs.mp3...
# Downloading from https://xeno-canto.org/749165/download to dataset\alaudala\XC749165-220610 MP-1525 11h22 id alouette des champs.mp3...
# Downloading from https://xeno-canto.org/749160/download to dataset\alaudala\XC749160-220610 MP-1522 10h45 id alouette des champs.mp3...
# Downloading from https://xeno-canto.org/735802/download to dataset\alaudala\XC735802-Skylark_Simple Song_Flight Call_Pec Pools_030522_A.mp3...
# Downloading from https://xeno-canto.org/733974/download to dataset\alaudala\XC733974-ALAARV2022-05-24-05-37-PAINUA-s-A.mp3...
# Downloading from https://xeno-canto.org/731731/download to dataset\alaudala\XC731731-Laverca.mp3...
# Downloading from https://xeno-canto.org/730636/download to dataset\alaudala\XC730636-Skylark_NorthMarshDundalk_.mp3...
# Downloading from https://xeno-canto.org/729685/download to dataset\alaudala\XC729685-Alouette des champs Chant Picadon 26 mai 14h.mp3...
# Downloading from https://xeno-canto.org/728574/download to dataset\alaudala\XC728574-220526_0754 0852 Feldlerche. HR, Otok Pag, Bridge to Vlasici near Dinjiska.mp3...
# Downloading from https://xeno-canto.org/727930/download to dataset\alaudala\XC727930-Skylark sand 29 may.mp3...
# Downloading from https://xeno-canto.org/727607/download to dataset\alaudala\XC727607-20100527_Feldlerchen.mp3...
# Downloading from https://xeno-canto.org/726583/download to dataset\alaudala\XC726583-Feldlerche 17052022 morgens.mp3...
# Downloading from https://xeno-canto.org/725289/download to dataset\alaudala\XC725289-Veldleeuweriken, zang met Koekoek-vrouw, Ederheide, 065022, 0855 uur.mp3...
# Downloading from https://xeno-canto.org/725100/download to dataset\alaudala\XC725100-ALAARV120522-T001_SONG (2).mp3...
# Downloading from https://xeno-canto.org/723496/download to dataset\alaudala\XC723496-Alauda arvensis_song_10_05_22_Almeida (online-audio-converter.com).mp3...
# Downloading from https://xeno-canto.org/722548/download to dataset\alaudala\XC722548-Skylark1_TMKH-1355_Long_Wood_2ndMay22.mp3...
# Downloading from https://xeno-canto.org/722501/download to dataset\alaudala\XC722501-alondra.mp3...
# Downloading from https://xeno-canto.org/722500/download to dataset\alaudala\XC722500-alondra.mp3...
# Downloading from https://xeno-canto.org/721864/download to dataset\alaudala\XC721864-FELDLERCHEN   Raist. Wiesen  9_11  VOC_220501_2643 A.mp3...
# Downloading from https://xeno-canto.org/721523/download to dataset\alaudala\XC721523-Alouette des champs, chant, Itteren, 02-05-22.mp3...
# Downloading from https://xeno-canto.org/721271/download to dataset\alaudala\XC721271-220501_13 Alauda arvensis 13.30 AS Rabadeiras forcarei.mp3...
# Downloading from https://xeno-canto.org/721268/download to dataset\alaudala\XC721268-220501_02 Alauda arvensis 12.30 fligh song AS rabadeiras, Forcarei.mp3...
# Downloading from https://xeno-canto.org/720044/download to dataset\alaudala\XC720044-Common Skylark Kilcoole Co Wicklow IRL 1.mp3...
# Downloading from https://xeno-canto.org/718610/download to dataset\alaudala\XC718610-ALAARV KAANSOO 220422_4128.mp3...
# Downloading from https://xeno-canto.org/717740/download to dataset\alaudala\XC717740-Skylark_Song + Mimicry of OC L etc_Tacumshin_16.04.22_B.mp3...
# Downloading from https://xeno-canto.org/717739/download to dataset\alaudala\XC717739-Skylark_Song + Apparent Mimicry of Crested Lark_Tacumshin_16.04.22_A++.mp3...
# Downloading from https://xeno-canto.org/717738/download to dataset\alaudala\XC717738-Skylark_Song + Apparent Mimicry of Crested Lark_Tacumshin_16.04.22_A_2.mp3...
# Downloading from https://xeno-canto.org/717658/download to dataset\alaudala\XC717658-220413_1117_Alouette des champs (chant)_Torxé (17.mp3...
# Downloading from https://xeno-canto.org/717650/download to dataset\alaudala\XC717650-Skylark_Song_Castlegregory_10.04.22_A++.mp3...
# Downloading from https://xeno-canto.org/717649/download to dataset\alaudala\XC717649-Skylark_Song_Castlegregory_10.04.22_A+.mp3...
# Downloading from https://xeno-canto.org/717648/download to dataset\alaudala\XC717648-Skylark_Song_Castlegregory_10.04.22_A_2.mp3...
# Downloading from https://xeno-canto.org/716621/download to dataset\alaudala\XC716621-220419_alaarv_song_1.mp3...
# Downloading from https://xeno-canto.org/714886/download to dataset\alaudala\XC714886-220412_1111_Alouette des champs (chant)2_Coux (17).mp3...
# Downloading from https://xeno-canto.org/714567/download to dataset\alaudala\XC714567-220410_Sånglärka.mp3...
# Downloading from https://xeno-canto.org/714358/download to dataset\alaudala\XC714358-FELDLERCHEN  31.03.20222  Kiesgr. Th.  9_25  VOC_220331-2518.mp3...
# Downloading from https://xeno-canto.org/713574/download to dataset\alaudala\XC713574-220406_1095_Alouette des champs (chant)_Antezant-la-Chapelle (17).mp3...
# Downloading from https://xeno-canto.org/711847/download to dataset\alaudala\XC711847-220318_19Alauda arvensis song in  hovering flight 19.30 As Rabadeiras, Forcarei.mp3...
# Downloading from https://xeno-canto.org/711721/download to dataset\alaudala\XC711721-skowronek śpiew 22.03.22.Przeciszów.mp3...
# Downloading from https://xeno-canto.org/711126/download to dataset\alaudala\XC711126-alauda dvorina2.mp3...
# Downloading from https://xeno-canto.org/710990/download to dataset\alaudala\XC710990-Skylark1.mp3...
# Downloading from https://xeno-canto.org/707130/download to dataset\alaudala\XC707130-Alouettedeschamps_11022022_courtilslarochetorin_15h30 chant vol.mp3...
# Downloading from https://xeno-canto.org/706370/download to dataset\alaudala\XC706370-birdnet_mobile_1330158844_recording_263.mp3...

# %% [markdown]
# ## Splitting sounds into 1 sec clips and trimming silence / parasitic noise

# %%
def preprocess_audio(file_path, target_dir, duration=1.0, sample_rate=16000):
    try:
        if file_path.endswith(".wav"):
            audio, _ = librosa.load(file_path, sr=sample_rate)
        elif file_path.endswith(".mp3"):
            audio_segment = AudioSegment.from_mp3(file_path)
            audio = audio_segment.set_frame_rate(sample_rate).set_channels(1).get_array_of_samples()
            audio = librosa.util.buf_to_float(audio)
        else:
            raise ValueError(f"Unsupported file format: {file_path}")

        trimmed_audio, _ = librosa.effects.trim(audio)
        target_samples = int(duration * sample_rate)
        num_segments = len(trimmed_audio) // target_samples

        for i in range(num_segments):
            start = i * target_samples
            end = start + target_samples
            segment = trimmed_audio[start:end]

            if not os.path.exists(target_dir):
                os.makedirs(target_dir)

            segment_path = os.path.join(target_dir, f"{os.path.splitext(os.path.basename(file_path))[0]}_{i}.wav")
            sf.write(segment_path, segment, sample_rate, 'PCM_16')
    except Exception as e:
        print(f"Erreur lors du traitement de {file_path}: {str(e)}")

def process_directory(dataset_path, output_root):
    for root, dirs, files in os.walk(dataset_path):
        for file in files:
            if file.endswith(".wav") or file.endswith(".mp3"):
                file_path = os.path.join(root, file)
                sub_dir = os.path.relpath(root, dataset_path)
                target_dir = os.path.join(output_root, sub_dir)
                print(f"Processing {file_path}...")
                preprocess_audio(file_path, target_dir)

dataset_path = "dataset"
output_root = "dataset_cleaned"
process_directory(dataset_path, output_root)

# %% [markdown]
# ## Load raw spoken digits data from Google Speech Commands

# %%
CLASSES = ['alauda', 'emberiza', 'muscicapa']
dataset_dir = Path('dataset_cleaned')
test_size_fraction = 0.2  # 20% des données pour l'ensemble de test
x = []
y = []
target_length = 16000  # Longueur cible pour tous les segments audio

for class_folder in CLASSES:
    files = list(dataset_dir.glob(f'{class_folder}/*'))
    for recording in files:
        data, sr = librosa.load(str(recording), sr=16000)
        data = librosa.util.fix_length(data, size=target_length)  # Ajustement de la longueur
        data = data.reshape(-1, 1)
        x.append(data)
        y.append(CLASSES.index(class_folder))

x = np.array(x, dtype=np.float32)
y = np.array(y)

# Trouver le nombre minimal d'échantillons parmi toutes les classes
min_size = min(np.sum(y == i) for i in range(len(CLASSES)))

# Sous-échantillonnage pour équilibrer les classes
indices_to_keep = []
for i in range(len(CLASSES)):
    indices = np.where(y == i)[0]
    np.random.shuffle(indices)
    indices_to_keep.extend(indices[:min_size])

# Utiliser uniquement les indices sélectionnés
x_balanced = x[indices_to_keep]
y_balanced = y[indices_to_keep]

# Divisez les données en ensembles d'entraînement et de test en utilisant la stratification
x_train, x_test, y_train, y_test = train_test_split(x_balanced, y_balanced, test_size=test_size_fraction, stratify=y_balanced)

# Convertir les étiquettes en représentation catégorielle
y_train = to_categorical(y_train, num_classes=len(CLASSES))
y_test = to_categorical(y_test, num_classes=len(CLASSES))

# Normalisation des données
x_mean = np.mean(x_train)
x_std = np.std(x_train)
x_train = (x_train - x_mean) / x_std
x_test = (x_test - x_mean) / x_std

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
unique_labels, counts = np.unique(y_test.argmax(axis=1), return_counts=True)
print(dict(zip(unique_labels, counts)))
# Out:
# (5390, 16000, 1) (5390, 3)
# (1348, 16000, 1) (1348, 3)
# {0: 449, 1: 449, 2: 450}

# %% [markdown]
# ## Prepare for inference with fixed-point Q7.9 samples by scaling input data accordingly

# %%
FIXED_POINT = 9
x_train /= 2**FIXED_POINT
x_test  /= 2**FIXED_POINT

# %% [markdown]
# ## Export small dataset (250 random vectors)

# %%
perms = np.random.permutation(len(y_test))[0:250]
x_test_250 = x_test[perms]
y_test_250 = y_test[perms]
np.savetxt('x_test_birds_250.csv', x_test_250.reshape((x_test_250.shape[0], -1)), delimiter=',', fmt='%s')
np.savetxt('y_test_birds_250.csv', y_test_250, delimiter=',', fmt='%s')

# %% [markdown]
# ## Build model M5

# %%
model = Sequential()
model.add(Input(shape=(16000, 1)))
model.add(MaxPool1D(pool_size=2, strides=2, padding='valid'))
model.add(Conv1D(filters=8, kernel_size=40, strides=4, activation='relu'))
model.add(MaxPool1D(pool_size=4, strides=4, padding='valid'))
model.add(Conv1D(filters=16, kernel_size=2, activation='relu'))
model.add(MaxPool1D(pool_size=4, strides=4, padding='valid'))
model.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPool1D(pool_size=4, strides=4, padding='valid'))
model.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPool1D(pool_size=4, strides=4, padding='valid'))
model.add(Flatten())
model.add(Dense(units=3))
model.add(Activation('softmax'))
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
model.summary()
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  max_pooling1d_132 (MaxPooli  (None, 8000, 1)          0
#  ng1D)
#
#  conv1d_108 (Conv1D)         (None, 1991, 8)           328
#
#  max_pooling1d_133 (MaxPooli  (None, 497, 8)           0
#  ng1D)
#
#  conv1d_109 (Conv1D)         (None, 496, 16)           272
#
#  max_pooling1d_134 (MaxPooli  (None, 124, 16)          0
#  ng1D)
#
#  conv1d_110 (Conv1D)         (None, 123, 32)           1056
#
#  max_pooling1d_135 (MaxPooli  (None, 30, 32)           0
#  ng1D)
#
#  conv1d_111 (Conv1D)         (None, 29, 32)            2080
#
#  max_pooling1d_136 (MaxPooli  (None, 7, 32)            0
#  ng1D)
#
#  flatten_17 (Flatten)        (None, 224)               0
#
#  dense_17 (Dense)            (None, 3)                 675
#
#  activation_17 (Activation)  (None, 3)                 0
#
# =================================================================
# Total params: 4,411
# Trainable params: 4,411
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
model.fit(x_train, y_train, epochs=50, batch_size=268, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 21/21 [==============================] - 3s 98ms/step - loss: 1.1004 - categorical_accuracy: 0.3393 - val_loss: 1.0983 - val_categorical_accuracy: 0.3338
# Epoch 2/50
# 21/21 [==============================] - 2s 89ms/step - loss: 1.0961 - categorical_accuracy: 0.3616 - val_loss: 1.0974 - val_categorical_accuracy: 0.3338
# Epoch 3/50
# 21/21 [==============================] - 2s 89ms/step - loss: 1.0883 - categorical_accuracy: 0.4061 - val_loss: 1.0763 - val_categorical_accuracy: 0.5059
# Epoch 4/50
# 21/21 [==============================] - 2s 88ms/step - loss: 1.0610 - categorical_accuracy: 0.4911 - val_loss: 1.0544 - val_categorical_accuracy: 0.4451
# Epoch 5/50
# 21/21 [==============================] - 2s 88ms/step - loss: 1.0172 - categorical_accuracy: 0.4935 - val_loss: 1.0879 - val_categorical_accuracy: 0.3553
# Epoch 6/50
# 21/21 [==============================] - 2s 87ms/step - loss: 0.9825 - categorical_accuracy: 0.5173 - val_loss: 0.9696 - val_categorical_accuracy: 0.5326
# Epoch 7/50
# 21/21 [==============================] - 2s 88ms/step - loss: 0.9215 - categorical_accuracy: 0.5642 - val_loss: 0.8729 - val_categorical_accuracy: 0.5831
# Epoch 8/50
# 21/21 [==============================] - 2s 95ms/step - loss: 0.8426 - categorical_accuracy: 0.6130 - val_loss: 0.8193 - val_categorical_accuracy: 0.6068
# Epoch 9/50
# 21/21 [==============================] - 2s 89ms/step - loss: 0.8180 - categorical_accuracy: 0.6263 - val_loss: 0.8081 - val_categorical_accuracy: 0.6224
# Epoch 10/50
# 21/21 [==============================] - 2s 92ms/step - loss: 0.8823 - categorical_accuracy: 0.5900 - val_loss: 0.7901 - val_categorical_accuracy: 0.6350
# Epoch 11/50
# 21/21 [==============================] - 2s 91ms/step - loss: 0.7771 - categorical_accuracy: 0.6538 - val_loss: 0.7825 - val_categorical_accuracy: 0.6550
# Epoch 12/50
# 21/21 [==============================] - 2s 93ms/step - loss: 0.7294 - categorical_accuracy: 0.6842 - val_loss: 0.7342 - val_categorical_accuracy: 0.7010
# Epoch 13/50
# 21/21 [==============================] - 2s 94ms/step - loss: 0.6615 - categorical_accuracy: 0.7288 - val_loss: 0.8765 - val_categorical_accuracy: 0.6024
# Epoch 14/50
# 21/21 [==============================] - 2s 93ms/step - loss: 0.6461 - categorical_accuracy: 0.7412 - val_loss: 0.6998 - val_categorical_accuracy: 0.7455
# Epoch 15/50
# 21/21 [==============================] - 2s 90ms/step - loss: 0.5984 - categorical_accuracy: 0.7716 - val_loss: 0.6268 - val_categorical_accuracy: 0.7982
# Epoch 16/50
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5386 - categorical_accuracy: 0.8007 - val_loss: 0.6677 - val_categorical_accuracy: 0.7463
# Epoch 17/50
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5236 - categorical_accuracy: 0.7941 - val_loss: 0.5466 - val_categorical_accuracy: 0.8012
# Epoch 18/50
# 21/21 [==============================] - 2s 92ms/step - loss: 0.4611 - categorical_accuracy: 0.8245 - val_loss: 0.5225 - val_categorical_accuracy: 0.8019
# Epoch 19/50
# 21/21 [==============================] - 2s 91ms/step - loss: 0.4457 - categorical_accuracy: 0.8332 - val_loss: 0.4539 - val_categorical_accuracy: 0.8279
# Epoch 20/50
# 21/21 [==============================] - 2s 88ms/step - loss: 0.4182 - categorical_accuracy: 0.8425 - val_loss: 0.4727 - val_categorical_accuracy: 0.8064
# Epoch 21/50
# 21/21 [==============================] - 2s 93ms/step - loss: 0.3974 - categorical_accuracy: 0.8499 - val_loss: 0.4582 - val_categorical_accuracy: 0.8101
# Epoch 22/50
# 21/21 [==============================] - 2s 91ms/step - loss: 0.3794 - categorical_accuracy: 0.8532 - val_loss: 0.5717 - val_categorical_accuracy: 0.7730
# Epoch 23/50
# 21/21 [==============================] - 2s 89ms/step - loss: 0.4090 - categorical_accuracy: 0.8397 - val_loss: 0.5080 - val_categorical_accuracy: 0.8286
# Epoch 24/50
# 21/21 [==============================] - 2s 93ms/step - loss: 0.3702 - categorical_accuracy: 0.8583 - val_loss: 0.4112 - val_categorical_accuracy: 0.8591
# Epoch 25/50
# 21/21 [==============================] - 2s 91ms/step - loss: 0.3685 - categorical_accuracy: 0.8545 - val_loss: 0.5331 - val_categorical_accuracy: 0.8138
# Epoch 26/50
# 21/21 [==============================] - 2s 93ms/step - loss: 0.3929 - categorical_accuracy: 0.8481 - val_loss: 0.4385 - val_categorical_accuracy: 0.8472
# Epoch 27/50
# 21/21 [==============================] - 2s 89ms/step - loss: 0.3461 - categorical_accuracy: 0.8631 - val_loss: 0.4151 - val_categorical_accuracy: 0.8309
# Epoch 28/50
# 21/21 [==============================] - 2s 95ms/step - loss: 0.3216 - categorical_accuracy: 0.8746 - val_loss: 0.3945 - val_categorical_accuracy: 0.8553
# Epoch 29/50
# 21/21 [==============================] - 2s 89ms/step - loss: 0.3260 - categorical_accuracy: 0.8683 - val_loss: 0.4395 - val_categorical_accuracy: 0.8450
# Epoch 30/50
# 21/21 [==============================] - 2s 90ms/step - loss: 0.3152 - categorical_accuracy: 0.8757 - val_loss: 0.3888 - val_categorical_accuracy: 0.8605
# Epoch 31/50
# 21/21 [==============================] - 2s 88ms/step - loss: 0.3022 - categorical_accuracy: 0.8811 - val_loss: 0.4173 - val_categorical_accuracy: 0.8420
# Epoch 32/50
# 21/21 [==============================] - 2s 91ms/step - loss: 0.3013 - categorical_accuracy: 0.8779 - val_loss: 0.4848 - val_categorical_accuracy: 0.8272
# Epoch 33/50
# 21/21 [==============================] - 2s 90ms/step - loss: 0.3113 - categorical_accuracy: 0.8755 - val_loss: 0.3981 - val_categorical_accuracy: 0.8553
# Epoch 34/50
# 21/21 [==============================] - 2s 93ms/step - loss: 0.2808 - categorical_accuracy: 0.8829 - val_loss: 0.4354 - val_categorical_accuracy: 0.8487
# Epoch 35/50
# 21/21 [==============================] - 2s 90ms/step - loss: 0.2822 - categorical_accuracy: 0.8891 - val_loss: 0.4070 - val_categorical_accuracy: 0.8479
# Epoch 36/50
# 21/21 [==============================] - 2s 87ms/step - loss: 0.2752 - categorical_accuracy: 0.8920 - val_loss: 0.5700 - val_categorical_accuracy: 0.8101
# Epoch 37/50
# 21/21 [==============================] - 2s 88ms/step - loss: 0.3190 - categorical_accuracy: 0.8766 - val_loss: 0.4040 - val_categorical_accuracy: 0.8680
# Epoch 38/50
# 21/21 [==============================] - 2s 91ms/step - loss: 0.2793 - categorical_accuracy: 0.8865 - val_loss: 0.4226 - val_categorical_accuracy: 0.8516
# Epoch 39/50
# 21/21 [==============================] - 2s 93ms/step - loss: 0.2780 - categorical_accuracy: 0.8853 - val_loss: 0.3755 - val_categorical_accuracy: 0.8650
# Epoch 40/50
# 21/21 [==============================] - 2s 96ms/step - loss: 0.3074 - categorical_accuracy: 0.8794 - val_loss: 0.3983 - val_categorical_accuracy: 0.8524
# Epoch 41/50
# 21/21 [==============================] - 2s 98ms/step - loss: 0.2852 - categorical_accuracy: 0.8872 - val_loss: 0.4257 - val_categorical_accuracy: 0.8561
# Epoch 42/50
# 21/21 [==============================] - 2s 94ms/step - loss: 0.2757 - categorical_accuracy: 0.8870 - val_loss: 0.3891 - val_categorical_accuracy: 0.8591
# Epoch 43/50
# 21/21 [==============================] - 2s 90ms/step - loss: 0.2583 - categorical_accuracy: 0.8913 - val_loss: 0.5684 - val_categorical_accuracy: 0.7841
# Epoch 44/50
# 21/21 [==============================] - 2s 90ms/step - loss: 0.3300 - categorical_accuracy: 0.8679 - val_loss: 0.4166 - val_categorical_accuracy: 0.8665
# Epoch 45/50
# 21/21 [==============================] - 2s 91ms/step - loss: 0.2786 - categorical_accuracy: 0.8894 - val_loss: 0.4153 - val_categorical_accuracy: 0.8635
# Epoch 46/50
# 21/21 [==============================] - 2s 95ms/step - loss: 0.2553 - categorical_accuracy: 0.8959 - val_loss: 0.3951 - val_categorical_accuracy: 0.8680
# Epoch 47/50
# 21/21 [==============================] - 2s 93ms/step - loss: 0.2484 - categorical_accuracy: 0.9020 - val_loss: 0.4360 - val_categorical_accuracy: 0.8464
# Epoch 48/50
# 21/21 [==============================] - 2s 92ms/step - loss: 0.2897 - categorical_accuracy: 0.8826 - val_loss: 0.3932 - val_categorical_accuracy: 0.8672
# Epoch 49/50
# 21/21 [==============================] - 2s 89ms/step - loss: 0.2486 - categorical_accuracy: 0.8996 - val_loss: 0.3746 - val_categorical_accuracy: 0.8717
# Epoch 50/50
# 21/21 [==============================] - 2s 89ms/step - loss: 0.2685 - categorical_accuracy: 0.8948 - val_loss: 0.3939 - val_categorical_accuracy: 0.8657

# %% [markdown]
# ## Evaluate model on test dataset

# %%
model.evaluate(x_test, y_test, verbose=2)
pred_test = model.predict(x_test)
print(tf.math.confusion_matrix(y_test.argmax(axis=1), pred_test.argmax(axis=1)))
# Out:
# 43/43 - 0s - loss: 0.3939 - categorical_accuracy: 0.8657 - 271ms/epoch - 6ms/step
# 43/43 [==============================] - 0s 5ms/step
# tf.Tensor(
# [[342  87  20]
#  [ 24 416   9]
#  [  9  32 409]], shape=(3, 3), dtype=int32)

# %% [markdown]
# ## Evaluate model on small dataset

# %%
model.evaluate(x_test_250, y_test_250, verbose=2)
pred_test_250 = model.predict(x_test_250)
print(tf.math.confusion_matrix(y_test_250.argmax(axis=1), pred_test_250.argmax(axis=1)))
# Out:
# 8/8 - 0s - loss: 0.3423 - categorical_accuracy: 0.8800 - 72ms/epoch - 9ms/step
# 8/8 [==============================] - 0s 6ms/step
# tf.Tensor(
# [[55  9  7]
#  [ 7 82  1]
#  [ 1  5 83]], shape=(3, 3), dtype=int32)

# %% [markdown]
# ## Save trained model

# %%
model.save('model.h5')

# %% [markdown]
# ## Remove SoftMax layer

# %%
if isinstance(model.layers[-1], Activation) and model.layers[-1].activation == softmax:
    model = tf.keras.Model(model.input, model.layers[-2].output, name=model.name)
else:
    print('Error: last layer is not SoftMax Activation')

# %% [markdown]
# ## Install Qualia-CodeGen for C inference code generation

# %%
#%pip install qualia_codegen_core
import qualia_codegen_core
from qualia_codegen_core.graph.KerasModelGraph import KerasModelGraph
from qualia_codegen_core.graph.Quantization import Quantization
from qualia_codegen_core.graph.RoundMode import RoundMode
#
from importlib.resources import files
main_path = str((files('qualia_codegen_core.examples')/'Linux'/'main.cpp').resolve())
print(main_path)
# Out:
# C:\Program Files\Python310\Lib\site-packages\qualia_codegen_core\examples\Linux\main.cpp

# %% [markdown]
# ## Convert Keras Model to Qualia-CodeGen's internal representation

# %%
modelgraph = KerasModelGraph(model).convert()
print(modelgraph)
# Out:
# —————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# Inputs                                           | Layer                                            | Outputs                                          | Input shape                                      | Output shape
# —————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#                                                  | input_26                                         | max_pooling1d_132                                | (1, 16000, 1)                                    | ((1, 16000, 1),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# input_26                                         | max_pooling1d_132                                | conv1d_108                                       | (1, 16000, 1)                                    | ((1, 8000, 1),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# max_pooling1d_132                                | conv1d_108                                       | max_pooling1d_133                                | (1, 8000, 1)                                     | ((1, 1991, 8),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# conv1d_108                                       | max_pooling1d_133                                | conv1d_109                                       | (1, 1991, 8)                                     | ((1, 497, 8),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# max_pooling1d_133                                | conv1d_109                                       | max_pooling1d_134                                | (1, 497, 8)                                      | ((1, 496, 16),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# conv1d_109                                       | max_pooling1d_134                                | conv1d_110                                       | (1, 496, 16)                                     | ((1, 124, 16),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# max_pooling1d_134                                | conv1d_110                                       | max_pooling1d_135                                | (1, 124, 16)                                     | ((1, 123, 32),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# conv1d_110                                       | max_pooling1d_135                                | conv1d_111                                       | (1, 123, 32)                                     | ((1, 30, 32),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# max_pooling1d_135                                | conv1d_111                                       | max_pooling1d_136                                | (1, 30, 32)                                      | ((1, 29, 32),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# conv1d_111                                       | max_pooling1d_136                                | flatten_17                                       | (1, 29, 32)                                      | ((1, 7, 32),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# max_pooling1d_136                                | flatten_17                                       | dense_17                                         | (1, 7, 32)                                       | ((1, 224),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# flatten_17                                       | dense_17                                         |                                                  | (1, 224)                                         | ((1, 3),)
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Generate C code for the trained model with 32-bit floating-point representation

# %%
float_modelgraph = copy.deepcopy(modelgraph)

# layer quantization annotations for float32
for node in float_modelgraph.nodes:
    # No scale factor if not fixed-point quantization on integers
    node.q = Quantization(
            number_type=float,
            width=32,
            long_width=32,
            weights_scale_factor=0,
            output_scale_factor=0,
            weights_round_mode=RoundMode.NONE,
            output_round_mode=RoundMode.NONE,
            )

float_res = qualia_codegen_core.Converter(output_path=Path('birds_output_floating')).convert_model(float_modelgraph)

with open('birds_model_floating.h', 'w') as f:
    f.write(float_res)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\conv1d
# ......vars
# .........0
# .........1
# ...layers\conv1d_1
# ......vars
# .........0
# .........1
# ...layers\conv1d_2
# ......vars
# .........0
# .........1
# ...layers\conv1d_3
# ......vars
# .........0
# .........1
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\flatten
# ......vars
# ...layers\input_layer
# ......vars
# ...layers\max_pooling1d
# ......vars
# ...layers\max_pooling1d_1
# ......vars
# ...layers\max_pooling1d_2
# ......vars
# ...layers\max_pooling1d_3
# ......vars
# ...layers\max_pooling1d_4
# ......vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2024-04-20 15:58:19         5044
# metadata.json                                  2024-04-20 15:58:19           64
# variables.h5                                   2024-04-20 15:58:19        46712
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2024-04-20 15:58:18         5044
# metadata.json                                  2024-04-20 15:58:18           64
# variables.h5                                   2024-04-20 15:58:18        46712
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\conv1d
# ......vars
# .........0
# .........1
# ...layers\conv1d_1
# ......vars
# .........0
# .........1
# ...layers\conv1d_2
# ......vars
# .........0
# .........1
# ...layers\conv1d_3
# ......vars
# .........0
# .........1
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\flatten
# ......vars
# ...layers\input_layer
# ......vars
# ...layers\max_pooling1d
# ......vars
# ...layers\max_pooling1d_1
# ......vars
# ...layers\max_pooling1d_2
# ......vars
# ...layers\max_pooling1d_3
# ......vars
# ...layers\max_pooling1d_4
# ......vars
# ...vars

# %% [markdown]
# ## Compile the 32-bit floating-point C code for x86 and evaluate on small dataset

# %%
# !g++ -std=c++17 -Wall -Wextra -pedantic -Ofast -o birds_floating -include birds_output_floating/include/defines.h -Ibirds_output_floating/include birds_output_floating/model.c "{main_path}"

import os

# Run the compiled program with the appropriate executable based on the OS
if os.name == 'posix':
    # !./birds_floating x_test_birds_250.csv y_test_birds_250.csv
else:
    # !birds_floating.exe x_test_birds_250.csv y_test_birds_250.csv
# Out:
# In file included from birds_output_floating/model.c:15:
# birds_output_floating/include/number.h: In function 'float scale_number_t_float(float, int, round_mode_t)':
# birds_output_floating/include/number.h:73:21: warning: unused parameter 'scale_factor' [-Wunused-parameter]
#    float number, int scale_factor, round_mode_t round_mode) {
#                  ~~~~^~~~~~~~~~~~
# birds_output_floating/include/number.h:73:48: warning: unused parameter 'round_mode' [-Wunused-parameter]
#    float number, int scale_factor, round_mode_t round_mode) {
#                                    ~~~~~~~~~~~~~^~~~~~~~~~
# birds_output_floating/include/number.h: In function 'float scale_and_clamp_to_number_t_float(float, int, round_mode_t)':
# birds_output_floating/include/number.h:81:21: warning: unused parameter 'scale_factor' [-Wunused-parameter]
#    float number, int scale_factor, round_mode_t round_mode) {
#                  ~~~~^~~~~~~~~~~~
# birds_output_floating/include/number.h:81:48: warning: unused parameter 'round_mode' [-Wunused-parameter]
#    float number, int scale_factor, round_mode_t round_mode) {
#                                    ~~~~~~~~~~~~~^~~~~~~~~~
# In file included from birds_output_floating/include/model.h:19,
#                  from C:\Program Files\Python310\Lib\site-packages\qualia_codegen_core\examples\Linux\main.cpp:12:
# birds_output_floating/include/number.h: In function 'float scale_number_t_float(float, int, round_mode_t)':
# birds_output_floating/include/number.h:73:21: warning: unused parameter 'scale_factor' [-Wunused-parameter]
#    float number, int scale_factor, round_mode_t round_mode) {
#                  ~~~~^~~~~~~~~~~~
# birds_output_floating/include/number.h:73:48: warning: unused parameter 'round_mode' [-Wunused-parameter]
#    float number, int scale_factor, round_mode_t round_mode) {
#                                    ~~~~~~~~~~~~~^~~~~~~~~~
# birds_output_floating/include/number.h: In function 'float scale_and_clamp_to_number_t_float(float, int, round_mode_t)':
# birds_output_floating/include/number.h:81:21: warning: unused parameter 'scale_factor' [-Wunused-parameter]
#    float number, int scale_factor, round_mode_t round_mode) {
#                  ~~~~^~~~~~~~~~~~
# birds_output_floating/include/number.h:81:48: warning: unused parameter 'round_mode' [-Wunused-parameter]
#    float number, int scale_factor, round_mode_t round_mode) {
#                                    ~~~~~~~~~~~~~^~~~~~~~~~
# Testing accuracy: 0.88

# %% [markdown]
# ## Generate C code for the trained model with 16-bit fixed-point representation

# %%
fixed_modelgraph = copy.deepcopy(modelgraph)

# layer quantization annotations for int16 Q9.7
for node in fixed_modelgraph.nodes:
    node.q = Quantization(
            number_type=int,
            width=16,
            long_width=32,
            weights_scale_factor=13,
            output_scale_factor=13,
            weights_round_mode=RoundMode.FLOOR,
            output_round_mode=RoundMode.FLOOR,
            )

fixed_res = qualia_codegen_core.Converter(output_path=Path('birds_output_fixed')).convert_model(fixed_modelgraph)

with open('birds_model_fixed.h', 'w') as f:
    f.write(fixed_res)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\conv1d
# ......vars
# .........0
# .........1
# ...layers\conv1d_1
# ......vars
# .........0
# .........1
# ...layers\conv1d_2
# ......vars
# .........0
# .........1
# ...layers\conv1d_3
# ......vars
# .........0
# .........1
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\flatten
# ......vars
# ...layers\input_layer
# ......vars
# ...layers\max_pooling1d
# ......vars
# ...layers\max_pooling1d_1
# ......vars
# ...layers\max_pooling1d_2
# ......vars
# ...layers\max_pooling1d_3
# ......vars
# ...layers\max_pooling1d_4
# ......vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2024-04-20 16:05:19         5044
# metadata.json                                  2024-04-20 16:05:19           64
# variables.h5                                   2024-04-20 16:05:19        46712
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2024-04-20 16:05:18         5044
# metadata.json                                  2024-04-20 16:05:18           64
# variables.h5                                   2024-04-20 16:05:18        46712
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\conv1d
# ......vars
# .........0
# .........1
# ...layers\conv1d_1
# ......vars
# .........0
# .........1
# ...layers\conv1d_2
# ......vars
# .........0
# .........1
# ...layers\conv1d_3
# ......vars
# .........0
# .........1
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\flatten
# ......vars
# ...layers\input_layer
# ......vars
# ...layers\max_pooling1d
# ......vars
# ...layers\max_pooling1d_1
# ......vars
# ...layers\max_pooling1d_2
# ......vars
# ...layers\max_pooling1d_3
# ......vars
# ...layers\max_pooling1d_4
# ......vars
# ...vars

# %% [markdown]
# ## Compile the 16-bit fixed-point C code for x86 and evaluate on small dataset

# %%
# !g++ -std=c++17 -Wall -Wextra -pedantic -Ofast -o birds_fixed -include birds_output_fixed/include/defines.h -Ibirds_output_fixed/include birds_output_fixed/model.c "{main_path}"

# Run the compiled program with the appropriate executable based on the OS
if os.name == 'posix':
    # !./birds_fixed x_test_birds_250.csv y_test_birds_250.csv
else:
    # !birds_fixed.exe x_test_birds_250.csv y_test_birds_250.csv
# Out:
# Testing accuracy: 0.776
